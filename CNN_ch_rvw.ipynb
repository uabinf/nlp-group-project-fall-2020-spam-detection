# %% [markdown]
# # Installation

# %%
# !pip install collection
# !pip install keras
# !pip install jieba

# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
import string
import jieba
# import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense

# %% [markdown]
# # Implementation

# %%
# read data

document = pd.read_csv("ICDM_REVIEWS_TO_RELEASE_encoding=gb18030.csv", encoding = "GB18030", header = None)
document
# Out:
#                0      1         2       3     4  \
# 0      review_id  label      user      ip  star
# 1        REVIEW0      +     USER1     IP1     5
# 2        REVIEW1      -     USER2     IP2     4
# 3        REVIEW2      +     USER3     IP3     5
# 4        REVIEW3      -     USER4     IP4     5
# ...          ...    ...       ...     ...   ...
# 9761  REVIEW9760      +  USER9063  IP4317     5
# 9762  REVIEW9761      -  USER9064    IP25     4
# 9763  REVIEW9762      +  USER9065  IP1687     5
# 9764  REVIEW9763      -  USER9066  IP5535     5
# 9765  REVIEW9764      +  USER9067  IP1859     5
#
#                                                       5
# 0                                                  text
# 1     他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2     鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3     跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4     我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# ...                                                 ...
# 9761  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
# [9766 rows x 6 columns]

# %%
# rename header

header = document.iloc[0]
document = document[1:]
document = document.rename(columns = header)
data = pd.DataFrame()
data["label"] = document["label"].copy()
data["text"] = document["text"].copy()

# %%
data
# Out:
#      label                                               text
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
# [9765 rows x 2 columns]

# %%
# remove punctuation, stopwords
# source of Chinese punct: https://github.com/tsroten/zhon/blob/develop/docs/index.rst

def tokenize(text):
    """Given a sentence remove its punctuation and stop words"""
    
    with open("stopwords.txt", 'r',encoding='GB18030') as f:
        stopwords = f.read().splitlines()
    
    l=list()
    seg_list = jieba.cut(text, cut_all=False)
    for seg in seg_list:
        if seg not in stopwords:
            l.append(seg)
    
    cleaned_text = [w for w in l if w not in stopwords] # removing stop-words
    return cleaned_text # using the first 10 tokens only

# %%
data["texts"] = data["text"].apply(tokenize)
data
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /scratch/local/jieba.cache
# Loading model cost 0.716 seconds.
# Prefix dict has been built successfully.
#      label                                               text  \
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
#                                                   texts
# 1     [他家, 面, 嚼, 劲, 牛肉汤, 味道, 服务员, 服务, 特别, 服务员, 顾存芳, ...
# 2     [鲜榨, 果汁, 不错, 水果, 新鲜, 口感, 小妹妹, 态度, 环境, 专家, 告诉, ...
# 3     [老婆, 二人, 世界, 就定, 他家, 一间, 包房, 他家, 挺, 老婆, 点, 几个,...
# 4     [开业, 那天, 环境, 一种, 温软, 感觉,  ,  , 服务, 销售, 耐心, 老公,...
# 5     [好像, 说, 宁波, 菜系, 东西, 上菜, 速度, 比较慢, 服务, 不错, 赠送, 餐...
# ...                                                 ...
# 9761  [苏浙, 汇吃, 新开, 家, 丰收, 日, 尝, 味道, 不错, 价格, 实惠, 贵, 包...
# 9762  [世界末日, 到来, 21, 号, 钱, 用光, TMD, 谁造, 谣, 剩, 100, 钱...
# 9763  [菜, 好吃, 剁, 椒, 鱼头, 强烈推荐, 建议, 老板, 稍微, 场地, 位置, 太,...
# 9764  [公司, 楼下,  , 好吃, 麻辣烫,  , 老板, 河南人,  , 煮, 麻辣烫, 小姑...
# 9765  [鸭, 王, 每桌, 点, 两道, 特价, 菜, 实惠, 菜, 味道, 周边, 朋友, 介绍...
#
# [9765 rows x 3 columns]

# %%
# labels to int   spam = 1, ham = 0

def label_to_num(label):
    return 1 if label == "+" else 0
data["labels"] = data["label"].apply(lambda x: label_to_num(x))



data
# Out:
#      label                                               text  \
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
#                                                   texts  labels
# 1     [他家, 面, 嚼, 劲, 牛肉汤, 味道, 服务员, 服务, 特别, 服务员, 顾存芳, ...       1
# 2     [鲜榨, 果汁, 不错, 水果, 新鲜, 口感, 小妹妹, 态度, 环境, 专家, 告诉, ...       0
# 3     [老婆, 二人, 世界, 就定, 他家, 一间, 包房, 他家, 挺, 老婆, 点, 几个,...       1
# 4     [开业, 那天, 环境, 一种, 温软, 感觉,  ,  , 服务, 销售, 耐心, 老公,...       0
# 5     [好像, 说, 宁波, 菜系, 东西, 上菜, 速度, 比较慢, 服务, 不错, 赠送, 餐...       0
# ...                                                 ...     ...
# 9761  [苏浙, 汇吃, 新开, 家, 丰收, 日, 尝, 味道, 不错, 价格, 实惠, 贵, 包...       1
# 9762  [世界末日, 到来, 21, 号, 钱, 用光, TMD, 谁造, 谣, 剩, 100, 钱...       0
# 9763  [菜, 好吃, 剁, 椒, 鱼头, 强烈推荐, 建议, 老板, 稍微, 场地, 位置, 太,...       1
# 9764  [公司, 楼下,  , 好吃, 麻辣烫,  , 老板, 河南人,  , 煮, 麻辣烫, 小姑...       0
# 9765  [鸭, 王, 每桌, 点, 两道, 特价, 菜, 实惠, 菜, 味道, 周边, 朋友, 介绍...       1
#
# [9765 rows x 4 columns]

# %%
# count unique words

def count_words(textset):
    count = Counter()
    max_tkn = 0
    for row in textset:
        i = 0
        for token in row:
            count[token] += 1
            i += 1
        max_tkn = i if i > max_tkn else max_tkn
    return count, max_tkn

words_statistic, max_token = count_words(data["texts"])
print(max_token)
print(len(words_statistic))
words_statistic
# Out:
# 832
# 22868
# Counter({'他家': 795,
#          '面': 661,
#          '嚼': 101,
#          '劲': 150,
#          '牛肉汤': 9,
#          '味道': 3931,
#          '服务员': 1738,
#          '服务': 2028,
#          '特别': 959,
#          '顾存芳': 194,
#          '特': 94,
#          '喜欢': 2585,
#          '鲜榨': 86,
#          '果汁': 138,
#          '不错': 5505,
#          '水果': 145,
#          '新鲜': 651,
#          '口感': 345,
#          '小妹妹': 5,
#          '态度': 435,
#          '环境': 1960,
#          '专家': 5,
#          '告诉': 61,
#          '吃水果': 9,
#          ' ': 24010,
#          '老婆': 60,
#          '二人': 4,
#          '世界': 17,
#          '就定': 10,
#          '一间': 25,
#          '包房': 256,
#          '挺': 1754,
#          '点': 1779,
#          '几个': 356,
#          '菜': 2132,
#          '吃': 7081,
#          '聊': 19,
#          '小姑娘': 148,
#          '两人': 17,
#          '打扰': 8,
#          '感到': 21,
#          '挺舒服': 18,
#          '开业': 77,
#          '那天': 77,
#          '一种': 110,
#          '温软': 1,
#          '感觉': 2116,
#          '销售': 28,
#          '耐心': 103,
#          '老公': 169,
#          '介绍': 287,
#          '口味': 1043,
#          '爆米花': 8,
#          '价格': 1084,
#          '性价比': 327,
#          '高': 273,
#          '总得来说': 7,
#          '服务态度': 380,
#          '实惠': 487,
#          '建议': 134,
#          '朋友': 1649,
#          '沃尔玛': 2,
#          '买': 658,
#          '~': 2977,
#          '好像': 294,
#          '说': 1617,
#          '宁波': 119,
#          '菜系': 25,
#          '东西': 851,
#          '上菜': 310,
#          '速度': 268,
#          '比较慢': 8,
#          '赠送': 26,
#          '餐前': 17,
#          '小吃': 105,
#          '送': 429,
#          '一点': 363,
#          '科学': 4,
#          '赞': 338,
#          '顺便': 66,
#          '零食': 17,
#          '热情': 537,
#          '2': 331,
#          '号线': 10,
#          '科技馆': 1,
#          '找': 262,
#          '好久': 63,
#          '地铁': 33,
#          '蛮远': 1,
#          '面包': 161,
#          '真心': 286,
#          '机会': 161,
#          '真想': 9,
#          '全买': 1,
#          '离谱': 9,
#          '红酒': 45,
#          '芝士': 131,
#          '超级': 256,
#          '满满的': 21,
#          '+_+': 2,
#          '昨天': 148,
#          '休息': 69,
#          '约': 86,
#          '鸭': 681,
#          '王': 285,
#          '想': 591,
#          '鸭子': 405,
#          '一只': 115,
#          '168': 30,
#          '元': 514,
#          '精品': 15,
#          '烤鸭': 1058,
#          '尝尝': 217,
#          '师傅': 72,
#          '片': 95,
#          '鸭架': 70,
#          '换汤': 2,
#          '鲜美': 146,
#          '下次': 872,
#          '选鸭王': 1,
#          '老牌子': 10,
#          '饭店': 611,
#          '外地': 15,
#          '时': 155,
#          '选择': 342,
#          '鸭王': 242,
#          '中': 182,
#          '烤鸭店': 25,
#          '太': 415,
#          '好吃': 2933,
#          '真的': 1430,
#          '实在': 254,
#          '没边': 1,
#          '难以形容': 1,
#          '甜品': 115,
#          '芋': 64,
#          '贵人': 63,
#          '前': 143,
#          '几天': 106,
#          '吃饭': 644,
#          '正好': 205,
#          '有人': 101,
#          '过生日': 62,
#          '帮': 209,
#          '蛋糕': 233,
#          '放进': 5,
#          '冰箱': 15,
#          '回族': 1,
#          '猪肉': 18,
#          '问': 159,
#          '汤底': 106,
#          '有没有': 28,
#          '主意': 1,
#          '单独': 7,
#          '点个': 29,
#          '小锅': 16,
#          '开水': 8,
#          '调料': 68,
#          '做': 1073,
#          '贴心': 68,
#          '奶茶': 397,
#          '手工': 40,
#          '很浓': 80,
#          '三明治': 22,
#          '肉': 451,
#          '美尔': 3,
#          '饿': 111,
#          '一杯': 245,
#          '足够': 39,
#          '这家': 1788,
#          '店': 1670,
#          '大地': 3,
#          '电影院': 6,
#          '对面': 71,
#          '多家': 26,
#          '小吃店': 9,
#          '5': 153,
#          '分熟': 9,
#          '倒': 257,
#          '下口': 3,
#          '咬': 40,
#          '不动': 9,
#          '7': 90,
#          '算了': 22,
#          '玉米汤': 2,
#          '鱼排': 7,
#          '挺嫩': 2,
#          '人去': 33,
#          '一份': 390,
#          'T': 10,
#          '骨': 54,
#          '45': 12,
#          '牛鱼': 1,
#          '双拼': 12,
#          '积分': 7,
#          '次': 62,
#          '免费送': 11,
#          '经典': 72,
#          '牛排': 188,
#          '价值': 12,
#          '35': 15,
#          '卖狗肉': 10,
#          '证明': 9,
#          '出处': 4,
#          '无耻': 5,
#          '商家': 17,
#          '倒霉': 8,
#          '第一次': 350,
#          '上海': 458,
#          '车站': 30,
#          '带我去': 24,
#          '来到': 110,
#          '康师傅': 489,
#          '我点': 62,
#          '新品': 72,
#          '金牌': 173,
#          '牛肉面': 661,
#          '宽': 20,
#          '汤': 503,
#          '这两点': 2,
#          '提前': 97,
#          '独立': 30,
#          '卫生间': 31,
#          '入口': 63,
#          '简单': 52,
#          '煮': 88,
#          '干丝': 9,
#          '烧': 163,
#          '油': 71,
#          '浓': 67,
#          '别提': 6,
#          '差': 392,
#          '鸡': 96,
#          '换换': 19,
#          '满意': 189,
#          '牛肉': 634,
#          '入味': 174,
#          '麻辣': 182,
#          '对胃口': 3,
#          '完': 254,
#          '意犹未尽': 9,
#          '刚去': 6,
#          '点评': 340,
#          '感想': 1,
#          '结婚': 43,
#          '酒店': 152,
#          '还行': 106,
#          '川菜': 43,
#          '团购': 393,
#          '双人': 17,
#          '套餐': 413,
#          '量': 377,
#          '两盆': 6,
#          '超多': 9,
#          '两个': 231,
#          '吃不完': 43,
#          '汤锅': 7,
#          '没什么': 202,
#          '特色': 465,
#          '土豆粉': 2,
#          '烧不烂': 1,
#          '炸豆': 1,
#          '皮超': 1,
#          '羊肉': 342,
#          '拼盘': 55,
#          '减少': 2,
#          '生菜': 21,
#          '吃不下': 18,
#          '店人': 3,
#          '超少': 2,
#          '四桌': 7,
#          '空调': 51,
#          '很小': 65,
#          '舒服': 229,
#          '别家': 44,
#          '一个样': 2,
#          '选': 138,
#          '红烧': 391,
#          '挺好吃': 131,
#          '点餐': 96,
#          '人员': 42,
#          '划算': 170,
#          '30': 97,
#          '块钱': 64,
#          '饱饱': 11,
#          '江': 46,
#          '想想': 115,
#          '一般般': 114,
#          '便宜': 386,
#          '安静': 159,
#          '!': 562,
#          '这厅': 1,
#          '很大': 344,
#          ',': 1599,
#          '家': 928,
#          '是从': 14,
#          '北京': 131,
#          '.': 663,
#          '火烤': 1,
#          '放心': 52,
#          '名以': 1,
#          '食为天': 1,
#          '万物': 1,
#          '土中生': 1,
#          '总': 73,
#          '菜肴': 79,
#          '学生': 34,
#          '记得': 88,
#          '虹桥': 62,
#          '火车站': 92,
#          '接': 23,
#          '私房': 241,
#          '秘制': 24,
#          '拌面': 63,
#          '牛': 72,
#          '三宝': 45,
#          '正点': 22,
#          '时间': 240,
#          '兄弟姐妹': 4,
#          '大厅': 90,
#          '吵闹': 16,
#          '小孩子': 30,
#          '哭': 8,
#          '闹': 7,
#          '清净': 10,
#          '再也': 50,
#          '周末': 135,
#          '开': 294,
#          '荒郊野外': 1,
#          '想以': 1,
#          '宴请': 73,
#          '可惜': 101,
#          '位置': 193,
#          '不佳': 3,
#          '客户群': 3,
#          '关门歇业': 1,
#          '晚上': 290,
#          '漆黑': 2,
#          '竹林': 6,
#          '建筑': 16,
#          '排': 86,
#          '十几': 3,
#          '二十分钟': 11,
#          '不算': 135,
#          '长': 76,
#          '一家': 713,
#          '吸引': 74,
#          '夸张': 15,
#          '中午': 329,
#          '一帮': 13,
#          '店铺': 54,
#          '新路': 5,
#          '高架': 4,
#          '装修': 420,
#          '气': 54,
#          '确实': 192,
#          '正宗': 307,
#          '阳澄湖': 20,
#          '大闸蟹': 64,
#          '鲜活': 4,
#          '蟹': 89,
#          '配有': 9,
#          '戒指': 3,
#          '查询': 2,
#          '防伪': 3,
#          '蟹黄': 20,
#          '爆满': 16,
#          '蟹肉': 18,
#          '蟹行': 11,
#          '天下': 18,
#          '聚会': 163,
#          '场所': 18,
#          '上次': 145,
#          '承接': 1,
#          '委员长': 1,
#          '同志': 7,
#          '委派': 1,
#          '外宾': 2,
#          '接待': 18,
#          '力': 50,
#          '木有': 28,
#          '开发': 8,
#          '新菜': 17,
#          '下班': 93,
#          '女朋友': 71,
#          '半只': 48,
#          '完整': 7,
#          '再点': 24,
#          '很快': 135,
#          '服务生': 50,
#          '勤快': 39,
#          '一顿饭': 37,
#          '骨碟': 3,
#          '换': 133,
#          '三个': 90,
#          '推荐': 775,
#          '试试': 169,
#          '绝味': 16,
#          '脖': 50,
#          '好多': 291,
#          '贵': 365,
#          '面条': 182,
#          '有劲': 49,
#          '道': 149,
#          '品种': 178,
#          '炖': 45,
#          '酥': 150,
#          '烂': 53,
#          '浓烈': 2,
#          '到位': 130,
#          '叫顾': 18,
#          '存芳': 18,
#          '周到': 152,
#          '友善': 5,
#          '下单': 13,
#          '超过': 15,
#          '分钟': 123,
#          '四个': 50,
#          '人点': 36,
#          '七个': 3,
#          '冷热': 4,
#          '菜全': 1,
#          '不见': 14,
#          '影子': 2,
#          '客人': 191,
#          '很香': 137,
#          '芥末': 97,
#          '鸭掌': 84,
#          '够味': 55,
#          '家庭聚会': 37,
#          '腐竹': 12,
#          '盖浇饭': 6,
#          '凉拌': 18,
#          '有时候': 80,
#          '分量': 194,
#          '行': 205,
#          '够': 107,
#          '辣': 262,
#          '老板': 784,
#          '客气': 70,
#          '鲜族': 1,
#          '先看': 2,
#          '菜单': 115,
#          '小贵': 109,
#          '一看': 61,
#          '量足': 18,
#          '食材': 90,
#          '冷冻': 8,
#          '嫌疑': 4,
#          '烤': 245,
#          '香': 269,
#          '地方': 822,
#          '还会': 315,
#          '泡': 42,
#          '菜汤': 8,
#          '合': 14,
#          '营业': 19,
#          '米兰': 1,
#          '汤是': 7,
#          '越式': 5,
#          '料': 83,
#          '太少': 53,
#          '搞': 81,
#          '阳春面': 4,
#          '价位': 46,
#          '吉亨': 1,
#          '四五倍': 1,
#          '回头': 4,
#          '就别': 2,
#          '顾客': 112,
#          '坑': 17,
#          '档次': 78,
#          '设计': 40,
#          '优雅': 118,
#          '气氛': 73,
#          '菜点': 7,
#          '蟹粉': 30,
#          '吃掉': 16,
#          '呼呼': 12,
#          '合口味': 16,
#          '足': 193,
#          '开心': 205,
#          '失望': 143,
#          '总想': 1,
#          '小费': 6,
#          '品尝': 139,
#          '几款': 9,
#          '新': 139,
#          '菜品': 220,
#          '异域': 1,
#          '风情': 24,
#          '适合': 391,
#          '?': 29,
#          '停车': 88,
#          '店面': 157,
#          '干净': 458,
#          '很足': 73,
#          '肉块': 8,
#          '牛骨': 9,
#          '熬出来': 11,
#          '汤汁': 60,
#          '好喝': 453,
#          '招牌': 198,
#          '大蒜': 10,
#          '炒': 59,
#          '牛舌': 21,
#          '美味': 257,
#          '那种': 227,
#          '青蒜': 2,
#          '从来不': 8,
#          '爆炒': 3,
#          '香气': 14,
#          '四溢': 13,
#          '好面': 4,
#          '汤类': 4,
#          '棒': 170,
#          '快餐店': 16,
#          '类': 46,
#          '值得称赞': 9,
#          '湘辣': 2,
#          '剁': 79,
#          '椒': 79,
#          '肥牛': 95,
#          '把面': 2,
#          '全是': 44,
#          '喝': 500,
#          '一口': 57,
#          '暖': 14,
#          '重': 48,
#          '香芹': 2,
#          '红油': 6,
#          '拌': 98,
#          '金针': 4,
#          '算是': 192,
#          '小菜': 161,
#          '每次': 403,
#          '吃面': 120,
#          '会点': 21,
#          '带去': 7,
#          '小料': 16,
#          '免费': 184,
#          '豆浆': 66,
#          '畅饮': 16,
#          '花生': 39,
#          '第三次': 6,
#          '发现': 265,
#          '两次': 43,
#          '不好意思': 37,
#          '没想到': 146,
#          '这是': 92,
#          '收钱': 9,
#          '1': 181,
#          '垃圾': 55,
#          '定好': 2,
#          '位子': 130,
#          '领班': 34,
#          '怎么回事': 5,
#          '理由': 13,
#          '真': 208,
#          '好笑': 1,
#          '原因': 64,
#          '付': 7,
#          '押金': 3,
#          '赶不回来': 1,
#          '来付': 1,
#          '再三': 1,
#          '没留': 1,
#          '难看': 8,
#          '死': 63,
#          '打电话': 46,
#          '预定': 73,
#          '同学': 114,
#          '冬瓜': 2,
#          '金针菇': 40,
#          '丸子': 32,
#          '种类': 79,
#          '宽敞': 56,
#          '拥挤': 13,
#          '常去': 14,
#          '灯': 31,
#          '很漂亮': 97,
#          '必点': 85,
#          '海鲜': 422,
#          '面疙瘩': 51,
#          '海瓜子': 183,
#          '茄子': 100,
#          '很多很多': 17,
#          '日本料理': 8,
#          '韩国': 61,
#          '料理': 56,
#          '样子': 137,
#          '随意': 19,
#          '专业': 58,
#          '卖': 104,
#          '伤不起': 4,
#          '萝卜': 7,
#          '腌制': 9,
#          '寿司': 31,
#          '咖喱': 79,
#          '虾': 270,
#          '难吃': 153,
#          '猪': 34,
#          '扒鸡': 1,
#          '扒': 6,
#          '去过': 181,
#          '光顾': 146,
#          '合算': 52,
#          '羊肉串': 25,
#          '飞饼': 71,
#          '远': 51,
#          '前天': 24,
#          '温馨': 117,
#          '捏': 8,
#          '泥巴': 1,
#          '坐': 161,
#          '现成': 2,
#          '胚子': 4,
#          '绘画': 10,
#          '店家': 114,
#          '负责': 15,
#          '一周': 18,
#          '通知': 8,
#          '取': 13,
#          '觉得很有': 6,
#          '希望': 291,
#          '常来': 11,
#          '整体': 82,
#          '小点': 9,
#          '冬天': 42,
#          '曲奇饼': 6,
#          '干': 61,
#          '夏天': 80,
#          '冰激凌': 29,
#          '搭配': 76,
#          '精美': 10,
#          '餐具': 34,
#          '无论是': 17,
#          '看书': 13,
#          '约会': 41,
#          '件': 4,
#          '惬意': 45,
#          '事': 28,
#          '店内': 63,
#          '小猫': 20,
#          '可爱': 107,
#          '悄悄': 1,
#          '跳上': 1,
#          '沙发': 41,
#          '安安静静': 7,
#          '乖乖': 3,
#          '摸': 2,
#          'wifi': 19,
#          '桌游': 24,
#          '书柜': 1,
#          '书': 14,
#          '提供': 55,
#          '寄': 16,
#          '明信片': 33,
#          '整家店': 1,
#          '休闲': 39,
#          '店里': 324,
#          '隔出': 1,
#          '一块': 76,
#          '天地': 5,
#          '每晚': 4,
#          '放': 119,
#          '电影': 67,
#          '44': 1,
#          '饮料': 306,
#          '加': 196,
#          '组合': 18,
#          '坐上': 3,
#          '下午': 127,
#          '时会': 3,
#          '添上': 3,
#          '柠檬水': 9,
#          '送上': 4,
#          '花茶': 4,
#          '普洱': 8,
#          '拿到': 34,
#          '优惠券': 19,
#          '试一试': 8,
#          '好不好': 12,
#          '两': 40,
#          '荤': 14,
#          '四素': 3,
#          '炒饭': 32,
#          '自助': 102,
#          '反正': 159,
#          '不用': 106,
#          '外面': 192,
#          '等位': 73,
#          '店菜': 2,
#          '地道': 131,
#          '鱼头': 138,
#          '嫩': 206,
#          '还来': 61,
#          '爽朗': 1,
#          '零头': 6,
#          '拉': 52,
#          '爆': 20,
#          '很赞': 81,
#          'O': 30,
#          '(': 125,
#          '∩': 28,
#          '_': 70,
#          ')': 160,
#          '大热': 2,
#          '天': 49,
#          '送来': 18,
#          '冰冰': 11,
#          '巧克力': 71,
#          '送人': 12,
#          '很棒': 122,
#          '好评': 52,
#          '好会': 1,
#          '促销': 4,
#          '试吃': 82,
#          '香芋': 28,
#          '蓝莓': 19,
#          '提拉': 21,
#          '米苏': 21,
#          '焦糖': 27,
#          '冰': 65,
#          '融化': 4,
#          '一会儿': 39,
#          '吃会': 1,
#          '总体': 305,
#          '逛': 69,
#          '大润发': 49,
#          '隔壁': 46,
#          '碗面': 11,
#          '龙头': 86,
#          '偏': 53,
#          '咸': 96,
#          '太小': 19,
#          '少': 263,
#          '不到': 164,
#          '要命': 10,
#          '半天': 60,
#          '人理': 11,
#          '草头': 5,
#          '里': 418,
#          '塑料纸': 1,
#          '不说': 13,
#          '嘴': 13,
#          '割破': 1,
#          '桌子': 128,
#          '关门': 78,
#          '菜谱': 11,
#          '老字号': 37,
#          '表演': 13,
#          '边乐': 1,
#          '纯正': 40,
#          '湖南': 11,
#          '土菜': 21,
#          '烧烤': 140,
#          '木炭': 2,
#          '超有': 5,
#          '超正': 1,
#          '碗': 91,
#          '不贵': 120,
#          '请客': 109,
#          '王订': 9,
#          '穿': 36,
#          '格格': 16,
#          '服': 14,
#          '迎宾': 67,
#          '领位': 4,
#          '带到': 14,
#          '靠窗': 30,
#          '环境卫生': 10,
#          '点单': 28,
#          '面带微笑': 9,
#          '笑': 19,
#          '好看': 99,
#          '有个': 141,
#          '小小的': 40,
#          '梨涡': 1,
#          '席间': 7,
#          '气派': 55,
#          '请客吃饭': 49,
#          '王蛮': 2,
#          '丢面子': 7,
#          '同事': 307,
#          '说芋': 2,
#          '几次': 184,
#          '鲜芋': 23,
#          '仙有': 1,
#          '区别': 33,
#          '离得': 7,
#          '风格': 133,
#          '皇宫': 16,
#          '气息': 19,
#          '十足': 44,
#          '养眼': 7,
#          '老爸': 28,
#          '老妈': 46,
#          '貌似': 127,
#          '旅游团': 2,
#          '名气': 22,
#          '大嘛': 2,
#          '值得': 325,
#          '推出': 37,
#          '满鼻': 2,
#          '色泽': 9,
#          '枣红': 3,
#          '油亮': 4,
#          '味美': 6,
#          '肉嫩': 10,
#          '奇香': 4,
#          '营养': 38,
#          '拔丝': 19,
#          '香蕉': 60,
#          '甜甜的': 44,
#          '水晶': 28,
#          '虾仁': 80,
#          '装点': 2,
#          '盘子': 46,
#          '大堂': 97,
#          '凉菜': 37,
#          '豆豉': 5,
#          '小黄鱼': 4,
#          '一塌糊涂': 13,
#          '菜来': 1,
#          '热菜': 106,
#          '98': 9,
#          '信价': 3,
#          '比太差': 1,
#          '酸菜鱼': 50,
#          '铁板': 34,
#          '酱': 98,
#          '清淡': 50,
#          '懒': 10,
#          '丰收': 178,
#          '日': 203,
#          '常客': 27,
#          '益气': 1,
#          '养生': 46,
#          '秋耳': 2,
#          '酸酸的': 20,
#          '挺不错': 265,
#          '月浦': 20,
#          '办': 101,
#          '婚宴': 42,
#          '市中心': 9,
#          '同级': 1,
#          'LEVEL': 1,
#          '低': 35,
#          '选在': 10,
#          '24': 13,
#          '小时': 105,
#          '经理人': 1,
#          '做生意': 16,
#          '住': 73,
#          '武威': 2,
#          '东路': 8,
#          '天冷': 12,
#          '还好': 245,
#          '外边': 3,
#          '搭': 20,
#          '帐篷': 2,
#          '叫外卖': 28,
#          '聊聊天': 39,
#          '爱': 349,
#          '哈哈哈': 149,
#          '〜': 362,
#          '午餐': 52,
#          '匆忙': 1,
#          '<': 8,
#          '遗憾': 21,
#          '改天': 11,
#          '色香': 2,
#          '啊啊啊': 190,
#          '终于': 71,
#          '在家': 42,
#          '噢': 37,
#          '两只': 20,
#          '喵': 14,
#          '星人': 4,
#          '一鸭': 21,
#          '片皮': 35,
#          '爽口': 78,
#          '配着': 11,
#          '一顿': 57,
#          '满嘴': 5,
#          '流油': 1,
#          '肥而': 31,
#          '不腻': 87,
#          '年纪': 8,
#          '诚恳': 2,
#          '但面': 4,
#          '相比': 40,
#          '相差': 5,
#          '甚远': 2,
#          '面量': 5,
#          '四块': 3,
#          '青菜': 53,
#          '一两个': 6,
#          '方便面': 132,
#          '一试': 34,
#          '给力': 43,
#          '招财猫': 4,
#          '猫': 24,
#          '蓝猫': 1,
#          '童鞋': 6,
#          '萌': 4,
#          '鸭舌': 48,
#          '我滴': 1,
#          '最爱': 37,
#          '哦哦哦': 14,
#          '卖相': 22,
#          '收费': 17,
#          '焖': 7,
#          '蹄面': 1,
#          '超': 111,
#          '花神': 101,
#          '咖啡馆': 61,
#          '优静': 1,
#          '几只': 9,
#          '路过': 229,
#          '随便': 203,
#          '回家': 135,
#          '一吃': 35,
#          '听说': 163,
#          '栗子': 8,
#          '出口': 7,
#          '大众': 76,
#          '网': 36,
#          '评论': 30,
#          '窝窝': 10,
#          '团': 43,
#          '贸然': 2,
#          '尝试': 126,
#          '体验': 52,
#          '点多': 17,
#          '餐厅': 288,
#          '3': 222,
#          '唯一': 62,
#          '一桌': 64,
#          '团上': 2,
#          '硬性': 1,
#          '点份餐': 1,
#          '无奈': 12,
#          '份': 114,
#          '披萨': 23,
#          '超贵': 1,
#          '100': 61,
#          '肋排': 11,
#          '满盘': 1,
#          '浇': 5,
#          '酱汁': 27,
#          '食欲': 51,
#          '有肉': 3,
#          '腥味': 17,
#          '放置': 3,
#          '一旁': 2,
#          '饭': 328,
#          '一个个': 23,
#          '幸好': 14,
#          '贝类': 5,
#          '买单': 75,
#          '提了': 5,
#          '无措': 1,
#          '支支吾吾': 1,
#          '解释': 20,
#          '交代': 3,
#          '出个': 3,
#          '店方': 4,
#          '回复': 1,
#          '赔钱': 2,
#          '降低': 4,
#          '品质': 58,
#          '索性': 6,
#          '带来': 19,
#          '不好': 191,
#          '影响': 29,
#          '家庭': 40,
#          '聚餐': 185,
#          '老来': 3,
#          '人多': 69,
#          '肯定': 140,
#          '放过': 6,
#          '味精': 32,
#          '系列': 27,
#          '不功': 1,
#          '型': 11,
#          '公司': 276,
#          '活动': 150,
#          '牌子': 41,
#          '味': 164,
#          '很甜': 39,
#          '很腻': 15,
#          '奶油味': 4,
#          '浓香': 8,
#          '相对来说': 11,
#          '原材料': 12,
#          '跟着': 22,
#          '小聚': 42,
#          '和蔼': 8,
#          ...})

# %%
# training and testing dataset

X_train_temp, X_test_temp, y_train, y_test = train_test_split(data["texts"], data["labels"], test_size = 0.2, shuffle = True, random_state = 0, stratify = data["labels"])

# %%
# tokenizer

tokenizer = Tokenizer(num_words = max_token)
tokenizer.fit_on_texts(X_train_temp)
word_index = tokenizer.word_index

# %%
# train sequences

X_train_sequences = tokenizer.texts_to_sequences(X_train_temp)
X_train = pad_sequences(X_train_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_train.shape
# Out:
# (7812, 832)

# %%
# test sequences

X_test_sequences = tokenizer.texts_to_sequences(X_test_temp)
X_test = pad_sequences(X_test_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_test.shape
# Out:
# (1953, 832)

# %%
# model

model = Sequential()
model.add(Embedding(len(words_statistic), 64, input_length = max_token))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 832, 64)           1463552
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 828, 128)          41088
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,505,941
# Trainable params: 1,505,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(X_train, y_train, epochs = 10, validation_data=(X_test, y_test), batch_size=10)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.6254 - accuracy: 0.6615 - val_loss: 0.6026 - val_accuracy: 0.6928
# Epoch 2/10
# 782/782 [==============================] - 11s 13ms/step - loss: 0.5470 - accuracy: 0.7232 - val_loss: 0.6107 - val_accuracy: 0.6897
# Epoch 3/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.4815 - accuracy: 0.7701 - val_loss: 0.6330 - val_accuracy: 0.6580
# Epoch 4/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3766 - accuracy: 0.8423 - val_loss: 0.7117 - val_accuracy: 0.6534
# Epoch 5/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.2402 - accuracy: 0.9100 - val_loss: 0.8891 - val_accuracy: 0.6528
# Epoch 6/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1311 - accuracy: 0.9590 - val_loss: 1.0953 - val_accuracy: 0.6585
# Epoch 7/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0750 - accuracy: 0.9807 - val_loss: 1.3875 - val_accuracy: 0.6068
# Epoch 8/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0591 - accuracy: 0.9855 - val_loss: 1.4588 - val_accuracy: 0.6339
# Epoch 9/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0519 - accuracy: 0.9873 - val_loss: 1.5310 - val_accuracy: 0.6380
# Epoch 10/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0437 - accuracy: 0.9907 - val_loss: 1.6077 - val_accuracy: 0.6441
