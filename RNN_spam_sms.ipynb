# %% [markdown]
# # Installation

# %%
# !pip install keras

# %%
# !pip install collection

# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd
import string
# import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.initializers import Constant
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Implementation

# %%
# read data

data = pd.read_csv("spam.csv", encoding = "latin-1", usecols = [0, 1], header = None)
data
# Out:
#          0                                                  1
# 0       v1                                                 v2
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
# [5573 rows x 2 columns]

# %%
# rename header

data.iloc[0][0] = "tags"
data.iloc[0][1] = "text"
header = data.iloc[0]
data = data[1:]
data = data.rename(columns = header)
data
# Out:
#       tags                                               text
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# 5      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# remove punctuation

def remove_punct(text):
    text_only = ''.join([char for char in text if char not in string.punctuation])
    return text_only



data["no_punct"] = data["text"].apply(lambda x: remove_punct(x))
data
# Out:
#       tags                                               text  \
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# 5      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
#                                                no_punct
# 1     Go until jurong point crazy Available only in ...
# 2                               Ok lar Joking wif u oni
# 3     Free entry in 2 a wkly comp to win FA Cup fina...
# 4           U dun say so early hor U c already then say
# 5     Nah I dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5568  This is the 2nd time we have tried 2 contact u...
# 5569                Will Ì b going to esplanade fr home
# 5570  Pity  was in mood for that Soany other suggest...
# 5571  The guy did some bitching but I acted like id ...
# 5572                          Rofl Its true to its name
#
# [5572 rows x 3 columns]

# %%
# remove stopwords

stop_words = set(stopwords.words("English"))

def tokenize(text):
    return [word.lower() for word in text.split() if word.lower() not in stop_words]



data["tokens"] = data["no_punct"].apply(lambda x: tokenize(x))
data
# Out:
#       tags                                               text  \
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# 5      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
#                                                no_punct  \
# 1     Go until jurong point crazy Available only in ...
# 2                               Ok lar Joking wif u oni
# 3     Free entry in 2 a wkly comp to win FA Cup fina...
# 4           U dun say so early hor U c already then say
# 5     Nah I dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5568  This is the 2nd time we have tried 2 contact u...
# 5569                Will Ì b going to esplanade fr home
# 5570  Pity  was in mood for that Soany other suggest...
# 5571  The guy did some bitching but I acted like id ...
# 5572                          Rofl Its true to its name
#
#                                                  tokens
# 1     [go, jurong, point, crazy, available, bugis, n...
# 2                        [ok, lar, joking, wif, u, oni]
# 3     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 4         [u, dun, say, early, hor, u, c, already, say]
# 5     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5568  [2nd, time, tried, 2, contact, u, u, å£750, po...
# 5569                 [ì, b, going, esplanade, fr, home]
# 5570                   [pity, mood, soany, suggestions]
# 5571  [guy, bitching, acted, like, id, interested, b...
# 5572                                 [rofl, true, name]
#
# [5572 rows x 4 columns]

# %%
# labels to int   spam = 1, ham = 0

def label_to_num(label):
    return 1 if label == "spam" else 0
data["labels"] = data["tags"].apply(lambda x: label_to_num(x))



data
# Out:
#       tags                                               text  \
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# 5      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
#                                                no_punct  \
# 1     Go until jurong point crazy Available only in ...
# 2                               Ok lar Joking wif u oni
# 3     Free entry in 2 a wkly comp to win FA Cup fina...
# 4           U dun say so early hor U c already then say
# 5     Nah I dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5568  This is the 2nd time we have tried 2 contact u...
# 5569                Will Ì b going to esplanade fr home
# 5570  Pity  was in mood for that Soany other suggest...
# 5571  The guy did some bitching but I acted like id ...
# 5572                          Rofl Its true to its name
#
#                                                  tokens  labels
# 1     [go, jurong, point, crazy, available, bugis, n...       0
# 2                        [ok, lar, joking, wif, u, oni]       0
# 3     [free, entry, 2, wkly, comp, win, fa, cup, fin...       1
# 4         [u, dun, say, early, hor, u, c, already, say]       0
# 5     [nah, dont, think, goes, usf, lives, around, t...       0
# ...                                                 ...     ...
# 5568  [2nd, time, tried, 2, contact, u, u, å£750, po...       1
# 5569                 [ì, b, going, esplanade, fr, home]       0
# 5570                   [pity, mood, soany, suggestions]       0
# 5571  [guy, bitching, acted, like, id, interested, b...       0
# 5572                                 [rofl, true, name]       0
#
# [5572 rows x 5 columns]

# %%
# count unique words

def count_words(textset):
    count = Counter()
    max_tkn = 0
    for row in textset:
        i = 0
        for token in row:
            count[token] += 1
            i += 1
        max_tkn = i if i > max_tkn else max_tkn
    return count, max_tkn

words_statistic, max_token = count_words(data["tokens"])
print(max_token)
print(len(words_statistic))
words_statistic
# Out:
# 80
# 9431
# Counter({'go': 278,
#          'jurong': 1,
#          'point': 13,
#          'crazy': 15,
#          'available': 16,
#          'bugis': 7,
#          'n': 143,
#          'great': 111,
#          'world': 33,
#          'la': 7,
#          'e': 84,
#          'buffet': 2,
#          'cine': 7,
#          'got': 238,
#          'amore': 1,
#          'wat': 96,
#          'ok': 277,
#          'lar': 38,
#          'joking': 6,
#          'wif': 27,
#          'u': 1119,
#          'oni': 4,
#          'free': 275,
#          'entry': 26,
#          '2': 478,
#          'wkly': 14,
#          'comp': 11,
#          'win': 71,
#          'fa': 4,
#          'cup': 8,
#          'final': 18,
#          'tkts': 4,
#          '21st': 3,
#          'may': 46,
#          '2005': 3,
#          'text': 188,
#          '87121': 4,
#          'receive': 38,
#          'questionstd': 2,
#          'txt': 163,
#          'ratetcs': 2,
#          'apply': 31,
#          '08452810075over18s': 2,
#          'dun': 55,
#          'say': 91,
#          'early': 33,
#          'hor': 2,
#          'c': 79,
#          'already': 90,
#          'nah': 10,
#          'dont': 279,
#          'think': 132,
#          'goes': 26,
#          'usf': 11,
#          'lives': 4,
#          'around': 61,
#          'though': 26,
#          'freemsg': 12,
#          'hey': 111,
#          'darling': 5,
#          '3': 66,
#          'weeks': 19,
#          'word': 34,
#          'back': 152,
#          'id': 32,
#          'like': 242,
#          'fun': 31,
#          'still': 153,
#          'tb': 4,
#          'xxx': 32,
#          'std': 9,
#          'chgs': 1,
#          'send': 190,
#          'å£150': 27,
#          'rcv': 2,
#          'even': 61,
#          'brother': 19,
#          'speak': 33,
#          'treat': 16,
#          'aids': 1,
#          'patent': 1,
#          'per': 58,
#          'request': 8,
#          'melle': 6,
#          'oru': 4,
#          'minnaminunginte': 3,
#          'nurungu': 3,
#          'vettam': 3,
#          'set': 20,
#          'callertune': 10,
#          'callers': 5,
#          'press': 10,
#          '9': 26,
#          'copy': 9,
#          'friends': 58,
#          'winner': 16,
#          'valued': 13,
#          'network': 29,
#          'customer': 58,
#          'selected': 29,
#          'receivea': 2,
#          'å£900': 7,
#          'prize': 92,
#          'reward': 10,
#          'claim': 113,
#          'call': 576,
#          '09061701461': 2,
#          'code': 30,
#          'kl341': 2,
#          'valid': 23,
#          '12': 14,
#          'hours': 21,
#          'mobile': 138,
#          '11': 9,
#          'months': 13,
#          'r': 153,
#          'entitled': 8,
#          'update': 24,
#          'latest': 39,
#          'colour': 21,
#          'mobiles': 12,
#          'camera': 36,
#          'co': 7,
#          '08002986030': 2,
#          'im': 462,
#          'gonna': 58,
#          'home': 162,
#          'soon': 59,
#          'want': 192,
#          'talk': 45,
#          'stuff': 43,
#          'anymore': 8,
#          'tonight': 59,
#          'k': 71,
#          'ive': 74,
#          'cried': 1,
#          'enough': 29,
#          'today': 141,
#          'six': 4,
#          'chances': 2,
#          'cash': 74,
#          '100': 16,
#          '20000': 2,
#          'pounds': 19,
#          'csh11': 2,
#          '87575': 4,
#          'cost': 33,
#          '150pday': 2,
#          '6days': 2,
#          '16': 50,
#          'tsandcs': 2,
#          'reply': 144,
#          'hl': 6,
#          '4': 287,
#          'info': 10,
#          'urgent': 65,
#          '1': 82,
#          'week': 115,
#          'membership': 3,
#          'å£100000': 2,
#          'jackpot': 2,
#          '81010': 2,
#          'tc': 23,
#          'wwwdbuknet': 2,
#          'lccltd': 2,
#          'pobox': 16,
#          '4403ldnw1a7rw18': 2,
#          'searching': 5,
#          'right': 92,
#          'words': 22,
#          'thank': 28,
#          'breather': 1,
#          'promise': 9,
#          'wont': 54,
#          'take': 126,
#          'help': 55,
#          'granted': 1,
#          'fulfil': 1,
#          'wonderful': 15,
#          'blessing': 2,
#          'times': 24,
#          'date': 18,
#          'sunday': 8,
#          'xxxmobilemovieclub': 1,
#          'use': 44,
#          'credit': 14,
#          'click': 7,
#          'wap': 10,
#          'link': 10,
#          'next': 62,
#          'message': 83,
#          'httpwap': 1,
#          'xxxmobilemovieclubcomnqjkgighjjgcbl': 1,
#          'oh': 112,
#          'kim': 1,
#          'watching': 34,
#          'eh': 12,
#          'remember': 31,
#          'spell': 3,
#          'name': 47,
#          'yes': 86,
#          'v': 52,
#          'naughty': 6,
#          'make': 101,
#          'wet': 5,
#          'fine': 45,
#          'thatåõs': 4,
#          'way': 101,
#          'feel': 62,
#          'gota': 1,
#          'b': 65,
#          'england': 10,
#          'macedonia': 1,
#          'miss': 76,
#          'goalsteam': 1,
#          'news': 17,
#          'ur': 384,
#          'national': 12,
#          'team': 6,
#          '87077': 8,
#          'eg': 12,
#          'trywales': 1,
#          'scotland': 3,
#          '4txtì¼120': 1,
#          'poboxox36504w45wq': 1,
#          'seriously': 9,
#          'i\x89û÷m': 5,
#          'going': 171,
#          'try': 48,
#          'ha': 16,
#          'ì': 117,
#          'pay': 31,
#          'first': 62,
#          'da': 131,
#          'stock': 5,
#          'comin': 11,
#          'aft': 19,
#          'finish': 42,
#          'lunch': 45,
#          'str': 4,
#          'lor': 160,
#          'ard': 21,
#          'smth': 16,
#          'ffffffffff': 1,
#          'alright': 23,
#          'meet': 78,
#          'sooner': 4,
#          'forced': 1,
#          'eat': 38,
#          'slice': 2,
#          'really': 86,
#          'hungry': 14,
#          'tho': 17,
#          'sucks': 7,
#          'mark': 8,
#          'getting': 50,
#          'worried': 9,
#          'knows': 10,
#          'sick': 9,
#          'turn': 4,
#          'pizza': 8,
#          'lol': 73,
#          'always': 56,
#          'convincing': 1,
#          'catch': 9,
#          'bus': 29,
#          'frying': 3,
#          'egg': 4,
#          'tea': 6,
#          'eating': 7,
#          'moms': 9,
#          'left': 30,
#          'dinner': 35,
#          'love': 195,
#          'amp': 82,
#          'packing': 1,
#          'car': 39,
#          'ill': 237,
#          'let': 70,
#          'know': 257,
#          'theres': 29,
#          'room': 34,
#          'ahhh': 1,
#          'work': 99,
#          'vaguely': 1,
#          'wait': 59,
#          'thats': 94,
#          'clear': 3,
#          'sure': 71,
#          'sarcastic': 2,
#          'x': 49,
#          'doesnt': 26,
#          'live': 46,
#          'us': 63,
#          'yeah': 86,
#          'apologetic': 1,
#          'fallen': 1,
#          'actin': 1,
#          'spoilt': 1,
#          'child': 3,
#          'caught': 3,
#          'till': 24,
#          'badly': 1,
#          'cheers': 8,
#          'tell': 137,
#          'anything': 73,
#          'fear': 3,
#          'fainting': 1,
#          'housework': 1,
#          'quick': 8,
#          'cuppa': 1,
#          'thanks': 74,
#          'subscription': 4,
#          'ringtone': 26,
#          'uk': 16,
#          'charged': 11,
#          'å£5month': 1,
#          'please': 128,
#          'confirm': 11,
#          'replying': 8,
#          'yup': 43,
#          'look': 31,
#          'timings': 1,
#          'msg': 81,
#          'xuhui': 3,
#          'learn': 7,
#          '2nd': 30,
#          'lesson': 17,
#          '8am': 2,
#          'oops': 10,
#          'roommates': 5,
#          'done': 49,
#          'see': 156,
#          'letter': 4,
#          'decide': 9,
#          'hello': 49,
#          'hows': 44,
#          'saturday': 16,
#          'texting': 6,
#          'youd': 8,
#          'decided': 16,
#          'tomo': 17,
#          'trying': 43,
#          'invite': 3,
#          'pls': 109,
#          'ahead': 7,
#          'watts': 1,
#          'wanted': 26,
#          'weekend': 30,
#          'abiola': 11,
#          'forget': 18,
#          'need': 166,
#          'crave': 11,
#          'sweet': 33,
#          'arabian': 1,
#          'steed': 1,
#          'mmmmmm': 2,
#          'yummy': 3,
#          '07732584351': 1,
#          'rodger': 1,
#          'burns': 2,
#          'tried': 22,
#          'sms': 42,
#          'nokia': 68,
#          'camcorder': 15,
#          '08000930705': 16,
#          'delivery': 22,
#          'tomorrow': 90,
#          'seeing': 14,
#          'hope': 103,
#          'man': 45,
#          'well': 133,
#          'endowed': 1,
#          'ltgt': 276,
#          'inches': 4,
#          'callsmessagesmissed': 3,
#          'calls': 24,
#          'didnt': 79,
#          'get': 386,
#          'hep': 1,
#          'immunisation': 1,
#          'nigeria': 8,
#          'fair': 3,
#          'hopefully': 5,
#          'tyler': 5,
#          'cant': 123,
#          'could': 60,
#          'maybe': 31,
#          'ask': 88,
#          'bit': 43,
#          'stubborn': 1,
#          'hospital': 10,
#          'kept': 7,
#          'telling': 14,
#          'weak': 5,
#          'sucker': 1,
#          'hospitals': 2,
#          'suckers': 1,
#          'thinked': 1,
#          'time': 208,
#          'saw': 23,
#          'class': 45,
#          'gram': 3,
#          'usually': 6,
#          'runs': 3,
#          'half': 38,
#          'eighth': 2,
#          'smarter': 1,
#          'gets': 11,
#          'almost': 13,
#          'whole': 14,
#          'second': 18,
#          'fyi': 6,
#          'ride': 5,
#          'morning': 77,
#          'hes': 32,
#          'crashing': 1,
#          'place': 59,
#          'wow': 12,
#          'never': 43,
#          'realized': 3,
#          'embarassed': 4,
#          'accomodations': 1,
#          'thought': 47,
#          'liked': 7,
#          'since': 27,
#          'best': 44,
#          'seemed': 4,
#          'happy': 106,
#          'cave': 1,
#          'sorry': 156,
#          'give': 99,
#          'offered': 1,
#          'embarassing': 1,
#          'ac': 4,
#          'sptv': 2,
#          'new': 136,
#          'jersey': 1,
#          'devils': 1,
#          'detroit': 2,
#          'red': 5,
#          'wings': 1,
#          'play': 38,
#          'ice': 8,
#          'hockey': 2,
#          'correct': 12,
#          'incorrect': 1,
#          'end': 39,
#          'mallika': 1,
#          'sherawat': 1,
#          'yesterday': 23,
#          'find': 73,
#          'lturlgt': 3,
#          'congrats': 18,
#          'year': 50,
#          'special': 43,
#          'cinema': 8,
#          'pass': 11,
#          '09061209465': 3,
#          'suprman': 3,
#          'matrix3': 3,
#          'starwars3': 3,
#          'etc': 13,
#          'bx420ip45we': 3,
#          '150pm': 6,
#          'later': 134,
#          'meeting': 43,
#          'reached': 10,
#          'yesgauti': 1,
#          'sehwag': 1,
#          'odi': 2,
#          'series': 4,
#          'pick': 71,
#          'burger': 3,
#          'move': 11,
#          'pain': 24,
#          'killing': 2,
#          'good': 234,
#          'joke': 5,
#          'girls': 16,
#          'situation': 9,
#          'seekers': 1,
#          'part': 31,
#          'checking': 11,
#          'iq': 4,
#          'took': 19,
#          'forever': 9,
#          'come': 226,
#          'double': 22,
#          'check': 38,
#          'hair': 24,
#          'dresser': 3,
#          'said': 86,
#          'wun': 7,
#          'cut': 13,
#          'short': 9,
#          'nice': 57,
#          'pleased': 6,
#          'advise': 3,
#          'following': 7,
#          'recent': 3,
#          'review': 6,
#          'mob': 24,
#          'awarded': 38,
#          'å£1500': 4,
#          'bonus': 21,
#          '09066364589': 2,
#          'song': 12,
#          'dedicated': 2,
#          'day': 202,
#          'dedicate': 2,
#          'valuable': 4,
#          'frnds': 14,
#          'rply': 10,
#          'complimentary': 12,
#          'trip': 21,
#          'eurodisinc': 2,
#          'trav': 2,
#          'acoentry41': 2,
#          'å£1000': 35,
#          'dis': 30,
#          '186å£150morefrmmob': 2,
#          'shracomorsglsuplt10': 2,
#          'ls1': 2,
#          '3aj': 2,
#          'hear': 32,
#          'divorce': 2,
#          'barbie': 1,
#          'comes': 21,
#          'kens': 1,
#          'plane': 5,
#          'month': 30,
#          'wah': 4,
#          'lucky': 17,
#          'save': 10,
#          'money': 57,
#          'hee': 13,
#          'finished': 19,
#          'hi': 131,
#          'babe': 78,
#          'wanna': 38,
#          'something': 68,
#          'xx': 11,
#          'kkwhere': 2,
#          'youhow': 1,
#          'performed': 1,
#          'waiting': 53,
#          'machan': 4,
#          'cool': 41,
#          'gentleman': 3,
#          'dignity': 3,
#          'respect': 3,
#          'peoples': 1,
#          'much': 113,
#          'shy': 2,
#          'pa': 32,
#          'operate': 1,
#          'looking': 29,
#          'job': 43,
#          'tas': 1,
#          'earn': 2,
#          'ah': 30,
#          'stop': 150,
#          'urgnt': 5,
#          'real': 36,
#          'yo': 37,
#          'tickets': 10,
#          'one': 170,
#          'jacket': 2,
#          'used': 15,
#          'multis': 1,
#          'started': 18,
#          'requests': 3,
#          'came': 27,
#          'bed': 32,
#          'coins': 4,
#          'factory': 1,
#          'gotta': 12,
#          'nitros': 2,
#          'ela': 2,
#          'kanoil': 1,
#          'download': 13,
#          'wen': 24,
#          'don\x89û÷t': 6,
#          'stand': 7,
#          'close': 18,
#          'you\x89û÷ll': 1,
#          'another': 37,
#          'night': 113,
#          'spent': 8,
#          'late': 56,
#          'afternoon': 27,
#          'casualty': 1,
#          'means': 26,
#          'havent': 46,
#          'stuff42moro': 1,
#          'includes': 1,
#          'sheets': 3,
#          'smile': 44,
#          'pleasure': 7,
#          'trouble': 8,
#          'pours': 2,
#          'rain': 9,
#          'sum1': 3,
#          'hurts': 8,
#          'becoz': 4,
#          'someone': 59,
#          'loves': 8,
#          'smiling': 20,
#          'service': 59,
#          'representative': 10,
#          '0800': 13,
#          '169': 2,
#          '6031': 2,
#          '10am9pm': 2,
#          'guaranteed': 50,
#          'å£5000': 20,
#          'planning': 8,
#          'buy': 65,
#          'lido': 3,
#          '530': 7,
#          'show': 25,
#          'collected': 3,
#          'simply': 6,
#          'password': 7,
#          'mix': 3,
#          '85069': 2,
#          'verify': 3,
#          'usher': 2,
#          'britney': 2,
#          'fml': 4,
#          'telugu': 1,
#          'moviewat': 1,
#          'abt': 26,
#          'loads': 11,
#          'loans': 2,
#          'wk': 23,
#          'hols': 4,
#          'run': 23,
#          'forgot': 31,
#          'hairdressers': 1,
#          'appointment': 4,
#          'four': 3,
#          'shower': 11,
#          'beforehand': 1,
#          'cause': 18,
#          'prob': 16,
#          'ham': 3,
#          'nothing': 38,
#          'else': 24,
#          'okay': 26,
#          'price': 24,
#          'long': 42,
#          'legal': 4,
#          'ave': 8,
#          'ams': 1,
#          'gone': 15,
#          '4the': 1,
#          'driving': 22,
#          'test': 22,
#          'yet': 50,
#          'youre': 53,
#          'mean': 20,
#          'guess': 38,
#          'gave': 10,
#          'boston': 5,
#          'men': 9,
#          'changed': 7,
#          'search': 17,
#          'location': 2,
#          'nyc': 4,
#          'cuz': 7,
#          'signin': 1,
#          'page': 7,
#          'says': 27,
#          'umma': 7,
#          'life': 77,
#          'vava': 3,
#          'lot': 34,
#          'dear': 110,
#          'wishes': 8,
#          'birthday': 36,
#          'making': 23,
#          'truly': 5,
#          'memorable': 1,
#          'aight': 33,
#          'hit': 14,
#          'would': 76,
#          'ip': 1,
#          'address': 21,
#          'considering': 4,
#          'computer': 12,
#          'isnt': 17,
#          'minecraft': 1,
#          'server': 1,
#          'grumpy': 1,
#          'old': 20,
#          'people': 50,
#          'mom': 12,
#          'better': 42,
#          'lying': 1,
#          'jokes': 5,
#          'worry': 22,
#          'busy': 19,
#          'plural': 1,
#          'noun': 2,
#          'research': 4,
#          'dinnermsg': 1,
#          'cos': 76,
#          'things': 53,
#          'scared': 5,
#          'mah': 13,
#          'loud': 3,
#          'gent': 2,
#          'contact': 68,
#          'last': 78,
#          'weekends': 10,
#          'draw': 43,
#          'shows': 36,
#          '09064012160': 2,
#          'k52': 3,
#          '12hrs': 17,
#          '150ppm': 34,
#          'wa': 3,
#          'openin': 1,
#          'sentence': 3,
#          'formal': 1,
#          'anyway': 27,
#          'juz': 25,
#          'tt': 4,
#          'eatin': 7,
#          'puttin': 2,
#          'weighthaha': 1,
#          'anythin': 3,
#          'happened': 16,
#          'entered': 11,
#          'cabin': 5,
#          'bday': 15,
#          'boss': 9,
#          'felt': 13,
#          'askd': 12,
#          'invited': 13,
#          'apartment': 8,
#          'went': 61,
#          'specially': 9,
#          'holiday': 44,
#          'flights': 6,
#          'inc': 8,
#          'operator': 15,
#          '0871277810910pmin': 1,
#          '18': 43,
#          'goodo': 2,
#          'must': 27,
#          'friday': 14,
#          'eggpotato': 1,
#          'ratio': 1,
#          'tortilla': 2,
#          'needed': 3,
#          'hmmmy': 1,
#          'uncle': 12,
#          'informed': 5,
#          'paying': 8,
#          'school': 27,
#          'directly': 6,
#          'food': 23,
#          'private': 19,
#          '2004': 8,
#          'account': 39,
#          'statement': 17,
#          '07742676969': 2,
#          '786': 4,
#          'unredeemed': 16,
#          'points': 20,
#          '08719180248': 2,
#          'identifier': 16,
#          '45239': 3,
#          'expires': 17,
#          'å£2000': 31,
#          'caller': 13,
#          '5903': 1,
#          'landline': 34,
#          '09064019788': 1,
#          'box42wr29c': 1,
#          'applespairsall': 1,
#          'malarky': 1,
#          'todays': 28,
#          'voda': 5,
#          'numbers': 13,
#          'ending': 9,
#          '7548': 1,
#          '350': 2,
#          'award': 29,
#          'match': 11,
#          '08712300220': 6,
#          'quoting': 5,
#          '4041': 1,
#          'standard': 6,
#          'rates': 10,
#          'app': 6,
#          'sao': 1,
#          'mu': 14,
#          'ìï': 52,
#          'predict': 1,
#          'ìll': 2,
#          'buying': 9,
#          'knowyetunde': 1,
#          'hasnt': 5,
#          'sent': 68,
#          'bother': 7,
#          'sending': 12,
#          'involve': 1,
#          'shouldnt': 5,
#          'imposed': 1,
#          'apologise': 3,
#          'girl': 34,
#          'del': 10,
#          'bak': 8,
#          'sum': 2,
#          'lucyxx': 1,
#          'kkhow': 4,
#          'tmorrowpls': 1,
#          'accomodate': 1,
#          'answer': 22,
#          'question': 19,
#          'sunshine': 9,
#          'quiz': 13,
#          'q': 6,
#          'top': 22,
#          'sony': 9,
#          'dvd': 8,
#          'player': 14,
#          'country': 7,
#          'algarve': 2,
#          'ansr': 4,
#          '82277': 5,
#          'sptyrone': 4,
#          'laid': 4,
#          'dogging': 11,
#          'locations': 5,
#          'direct': 12,
#          'join': 27,
#          'uks': 10,
#          'largest': 4,
#          'bt': 23,
#          'txting': 11,
#          'gravel': 1,
#          '69888': 2,
#          'nt': 15,
#          'ec2a': 4,
#          '31pmsg150p': 2,
#          'haf': 23,
#          'msn': 2,
#          'yijuehotmailcom': 1,
#          'rooms': 5,
#          'befor': 4,
#          'activities': 4,
#          'youll': 14,
#          'msgs': 13,
#          'chat': 56,
#          'svc': 1,
#          'hardcore': 3,
#          'services': 18,
#          '69988': 1,
#          'age': 13,
#          'yr': 14,
#          'lazy': 9,
#          'type': 15,
#          'lect': 9,
#          'pouch': 2,
#          'sir': 34,
#          'mail': 24,
#          'swt': 2,
#          'nver': 1,
#          'tired': 12,
#          'little': 30,
#          'lovable': 10,
#          'persons': 7,
#          'cozsomtimes': 1,
#          'occupy': 2,
#          'biggest': 4,
#          'hearts': 1,
#          'gud': 53,
#          'ni8': 12,
#          'open': 17,
#          'ya': 56,
#          'dot': 3,
#          'whats': 33,
#          'staff': 2,
#          'taking': 18,
#          'replied': 6,
#          'randy': 2,
#          'sexy': 27,
#          'female': 3,
#          'local': 6,
#          'luv': 34,
#          'netcollex': 4,
#          'ltd': 15,
#          '08700621170150p': 2,
#          'ummmawill': 1,
#          'inour': 1,
#          'begin': 5,
#          'qatar': 4,
#          'pray': 8,
#          'hard': 16,
#          'ki': 6,
#          'deleted': 4,
#          'sindu': 1,
#          'birla': 3,
#          'soft': 3,
#          'wine': 11,
#          'flowing': 2,
#          'nevering': 1,
#          'thk': 50,
#          'plaza': 2,
#          'typical': 1,
#          'everywhere': 2,
#          'dirt': 1,
#          'floor': 3,
#          'windows': 2,
#          'shirt': 4,
#          'sometimes': 8,
#          'mouth': 2,
#          'dream': 10,
#          'without': 28,
#          'chores': 1,
#          'joy': 4,
#          'lots': 17,
#          'tv': 28,
#          'exist': 1,
#          'hail': 1,
#          'mist': 1,
#          'become': 6,
#          'aaooooright': 1,
#          'leaving': 19,
#          'house': 36,
#          'interview': 4,
#          'boy': 30,
#          'meare': 1,
#          'missing': 27,
#          'annoncement': 1,
#          'years': 25,
#          '07046744435': 1,
#          'arrange': 6,
#          '0871277810810': 2,
#          'keep': 68,
#          'safe': 11,
#          'envy': 1,
#          'everyone': 18,
#          'sees': 1,
#          'parentsi': 1,
#          'hand': 15,
#          'excited': 1,
#          'spend': 10,
#          'bootydelious': 1,
#          '32f': 1,
#          'inviting': 6,
#          'friend': 47,
#          'yes434': 1,
#          'no434': 1,
#          'wwwsmsacubootydelious': 1,
#          'frnd': 16,
#          '62468': 6,
#          'bangbabes': 1,
#          'order': 21,
#          'content': 15,
#          'goto': 8,
#          'bangb': 1,
#          'internetservice': 1,
#          'menu': 7,
#          'cultures': 1,
#          'module': 2,
#          '09061701939': 1,
#          's89': 1,
#          'avoid': 2,
#          'missunderstding': 1,
#          'wit': 15,
#          'beloved': 2,
#          'ones': 10,
#          'escape': 4,
#          'fancy': 14,
#          'bridge': 1,
#          'needs': 16,
#          'lager': 1,
#          'completely': 9,
#          'formclark': 2,
#          'also': 71,
#          'utter': 2,
#          'waste': 7,
#          'axis': 1,
#          'bank': 14,
#          'hmmm': 9,
#          'hop': 7,
#          'muz': 11,
#          'discuss': 5,
#          'liao': 35,
#          'coming': 50,
#          'bloody': 4,
#          'hell': 12,
#          'believe': 20,
#          'surname': 1,
#          ...})

# %%
# training and testing dataset

X_train_temp, X_test_temp, y_train, y_test = train_test_split(data["tokens"], data["labels"], test_size = 0.2, shuffle = True, random_state = 0, stratify = data["labels"])

# %%
# tokenizer

tokenizer = Tokenizer(num_words = max_token)
tokenizer.fit_on_texts(X_train_temp)
word_index = tokenizer.word_index
word_index
# Out:
# {'u': 1,
#  'call': 2,
#  '2': 3,
#  'im': 4,
#  'ur': 5,
#  'get': 6,
#  '4': 7,
#  'ltgt': 8,
#  'go': 9,
#  'free': 10,
#  'ok': 11,
#  'dont': 12,
#  'know': 13,
#  'ill': 14,
#  'got': 15,
#  'like': 16,
#  'good': 17,
#  'come': 18,
#  'time': 19,
#  'day': 20,
#  'send': 21,
#  'want': 22,
#  'love': 23,
#  'text': 24,
#  'one': 25,
#  'r': 26,
#  'need': 27,
#  'going': 28,
#  'txt': 29,
#  'home': 30,
#  'back': 31,
#  'lor': 32,
#  'still': 33,
#  'today': 34,
#  'sorry': 35,
#  'stop': 36,
#  'n': 37,
#  'tell': 38,
#  'see': 39,
#  'reply': 40,
#  'mobile': 41,
#  'later': 42,
#  'hi': 43,
#  'new': 44,
#  'think': 45,
#  'cant': 46,
#  'please': 47,
#  'da': 48,
#  'phone': 49,
#  'well': 50,
#  'week': 51,
#  'ì': 52,
#  'happy': 53,
#  'take': 54,
#  'night': 55,
#  'hey': 56,
#  'dear': 57,
#  'oh': 58,
#  'great': 59,
#  'pls': 60,
#  'claim': 61,
#  'much': 62,
#  'hope': 63,
#  'make': 64,
#  'work': 65,
#  'give': 66,
#  'thats': 67,
#  'number': 68,
#  'prize': 69,
#  'say': 70,
#  'way': 71,
#  'ask': 72,
#  'said': 73,
#  'wat': 74,
#  'right': 75,
#  'already': 76,
#  'yes': 77,
#  '1': 78,
#  'cos': 79,
#  'yeah': 80,
#  'didnt': 81,
#  'c': 82,
#  'message': 83,
#  'amp': 84,
#  'msg': 85,
#  'really': 86,
#  'ive': 87,
#  'miss': 88,
#  'meet': 89,
#  'cash': 90,
#  'would': 91,
#  'keep': 92,
#  'last': 93,
#  'morning': 94,
#  'babe': 95,
#  'find': 96,
#  'pick': 97,
#  'life': 98,
#  'thanks': 99,
#  'win': 100,
#  'let': 101,
#  'went': 102,
#  'also': 103,
#  'tomorrow': 104,
#  'k': 105,
#  'something': 106,
#  'every': 107,
#  'sure': 108,
#  'lol': 109,
#  'e': 110,
#  '3': 111,
#  'contact': 112,
#  'sent': 113,
#  'care': 114,
#  'even': 115,
#  'nokia': 116,
#  'anything': 117,
#  'gonna': 118,
#  'place': 119,
#  'thing': 120,
#  'many': 121,
#  'buy': 122,
#  'someone': 123,
#  'soon': 124,
#  'us': 125,
#  'b': 126,
#  'urgent': 127,
#  'chat': 128,
#  'per': 129,
#  'first': 130,
#  'wait': 131,
#  'next': 132,
#  'could': 133,
#  'money': 134,
#  'around': 135,
#  'tonight': 136,
#  'help': 137,
#  'always': 138,
#  'late': 139,
#  'feel': 140,
#  'service': 141,
#  'wan': 142,
#  'gud': 143,
#  'friends': 144,
#  'coming': 145,
#  'customer': 146,
#  'leave': 147,
#  'things': 148,
#  'sleep': 149,
#  'dun': 150,
#  'wish': 151,
#  'friend': 152,
#  'told': 153,
#  'youre': 154,
#  'year': 155,
#  'may': 156,
#  'done': 157,
#  'haha': 158,
#  'man': 159,
#  'getting': 160,
#  'ya': 161,
#  'tone': 162,
#  'people': 163,
#  'x': 164,
#  '16': 165,
#  'nice': 166,
#  'try': 167,
#  'ìï': 168,
#  'live': 169,
#  'yet': 170,
#  'wont': 171,
#  'v': 172,
#  'fine': 173,
#  'hello': 174,
#  'smile': 175,
#  'hows': 176,
#  'lunch': 177,
#  'mind': 178,
#  'waiting': 179,
#  '5': 180,
#  'thought': 181,
#  'meeting': 182,
#  'guaranteed': 183,
#  'never': 184,
#  'min': 185,
#  'thk': 186,
#  '18': 187,
#  'name': 188,
#  'job': 189,
#  'heart': 190,
#  'talk': 191,
#  'havent': 192,
#  'use': 193,
#  'guess': 194,
#  'bit': 195,
#  'mins': 196,
#  'ready': 197,
#  'yup': 198,
#  'class': 199,
#  'better': 200,
#  'best': 201,
#  'special': 202,
#  'line': 203,
#  'eat': 204,
#  'play': 205,
#  'birthday': 206,
#  'trying': 207,
#  'stuff': 208,
#  'holiday': 209,
#  'guys': 210,
#  'latest': 211,
#  'check': 212,
#  'awarded': 213,
#  'long': 214,
#  'camera': 215,
#  'end': 216,
#  'finish': 217,
#  'liao': 218,
#  'person': 219,
#  'room': 220,
#  'days': 221,
#  'cool': 222,
#  'lar': 223,
#  'another': 224,
#  'car': 225,
#  'quite': 226,
#  'box': 227,
#  'receive': 228,
#  'sms': 229,
#  'half': 230,
#  'id': 231,
#  'maybe': 232,
#  'draw': 233,
#  '1st': 234,
#  'nothing': 235,
#  'big': 236,
#  'girl': 237,
#  'ever': 238,
#  'might': 239,
#  'easy': 240,
#  'shit': 241,
#  'forgot': 242,
#  'wanna': 243,
#  'den': 244,
#  'enjoy': 245,
#  'account': 246,
#  'actually': 247,
#  'bad': 248,
#  'yo': 249,
#  'plan': 250,
#  'landline': 251,
#  'chance': 252,
#  'word': 253,
#  'po': 254,
#  'baby': 255,
#  'å£2000': 256,
#  'real': 257,
#  'face': 258,
#  'sweet': 259,
#  'weekend': 260,
#  'minutes': 261,
#  'hear': 262,
#  'dinner': 263,
#  'look': 264,
#  'luv': 265,
#  'problem': 266,
#  'house': 267,
#  'video': 268,
#  'little': 269,
#  '2nd': 270,
#  'shows': 271,
#  'sir': 272,
#  'dat': 273,
#  'working': 274,
#  'early': 275,
#  'bed': 276,
#  'cost': 277,
#  'called': 278,
#  'left': 279,
#  'aight': 280,
#  'pa': 281,
#  'shes': 282,
#  'hes': 283,
#  '6': 284,
#  'jus': 285,
#  'thanx': 286,
#  '150ppm': 287,
#  'probably': 288,
#  'orange': 289,
#  'kiss': 290,
#  'anyway': 291,
#  'bus': 292,
#  'entry': 293,
#  'å£1000': 294,
#  'sexy': 295,
#  'remember': 296,
#  'says': 297,
#  'start': 298,
#  'speak': 299,
#  'princess': 300,
#  'wake': 301,
#  'shall': 302,
#  'tcs': 303,
#  'offer': 304,
#  'part': 305,
#  'watch': 306,
#  'selected': 307,
#  'award': 308,
#  'theres': 309,
#  'put': 310,
#  '7': 311,
#  'shopping': 312,
#  'wanted': 313,
#  'came': 314,
#  'world': 315,
#  'watching': 316,
#  'code': 317,
#  'boy': 318,
#  'wif': 319,
#  'whats': 320,
#  'collection': 321,
#  'hour': 322,
#  'xmas': 323,
#  'hav': 324,
#  'month': 325,
#  'todays': 326,
#  'fun': 327,
#  'ah': 328,
#  'apply': 329,
#  'pay': 330,
#  'abt': 331,
#  'enough': 332,
#  'attempt': 333,
#  'years': 334,
#  'network': 335,
#  'looking': 336,
#  'god': 337,
#  'reach': 338,
#  'join': 339,
#  'texts': 340,
#  'important': 341,
#  'afternoon': 342,
#  'ringtone': 343,
#  'tones': 344,
#  'two': 345,
#  'lot': 346,
#  'dad': 347,
#  'mail': 348,
#  'bt': 349,
#  'stay': 350,
#  'asked': 351,
#  'å£150': 352,
#  'means': 353,
#  'bring': 354,
#  'times': 355,
#  'leh': 356,
#  'hurt': 357,
#  'tmr': 358,
#  'mob': 359,
#  'made': 360,
#  'doesnt': 361,
#  'fuck': 362,
#  'wk': 363,
#  'everything': 364,
#  'without': 365,
#  'able': 366,
#  'dunno': 367,
#  'must': 368,
#  'tv': 369,
#  'music': 370,
#  'run': 371,
#  'away': 372,
#  'bonus': 373,
#  'office': 374,
#  'since': 375,
#  'dis': 376,
#  '8007': 377,
#  'book': 378,
#  'making': 379,
#  'til': 380,
#  'though': 381,
#  'driving': 382,
#  'goes': 383,
#  'collect': 384,
#  'hot': 385,
#  'evening': 386,
#  'sat': 387,
#  'xxx': 388,
#  'update': 389,
#  'juz': 390,
#  'rate': 391,
#  'answer': 392,
#  'thank': 393,
#  'guy': 394,
#  'calls': 395,
#  'words': 396,
#  'details': 397,
#  'wot': 398,
#  'bored': 399,
#  'tot': 400,
#  'saw': 401,
#  'school': 402,
#  'plus': 403,
#  'thinking': 404,
#  'valid': 405,
#  'double': 406,
#  'hair': 407,
#  'till': 408,
#  '500': 409,
#  'haf': 410,
#  '150p': 411,
#  'plz': 412,
#  'calling': 413,
#  'show': 414,
#  'weekly': 415,
#  'either': 416,
#  'oso': 417,
#  'pain': 418,
#  'change': 419,
#  'leaving': 420,
#  'ltdecimalgt': 421,
#  'story': 422,
#  'minute': 423,
#  'game': 424,
#  'lose': 425,
#  'wife': 426,
#  'order': 427,
#  'mean': 428,
#  'sch': 429,
#  'else': 430,
#  '9': 431,
#  'okay': 432,
#  'worry': 433,
#  'nite': 434,
#  'colour': 435,
#  'aft': 436,
#  'smiling': 437,
#  'goin': 438,
#  'address': 439,
#  'tc': 440,
#  'alright': 441,
#  'congrats': 442,
#  'believe': 443,
#  'food': 444,
#  'poly': 445,
#  'town': 446,
#  'huh': 447,
#  'sae': 448,
#  'dude': 449,
#  'hours': 450,
#  'noe': 451,
#  'friendship': 452,
#  'test': 453,
#  'together': 454,
#  'okie': 455,
#  'price': 456,
#  'online': 457,
#  'simple': 458,
#  'club': 459,
#  'busy': 460,
#  'question': 461,
#  'points': 462,
#  'gr8': 463,
#  '86688': 464,
#  'wen': 465,
#  'everyone': 466,
#  'yesterday': 467,
#  'tried': 468,
#  'close': 469,
#  'found': 470,
#  'saying': 471,
#  'g': 472,
#  'await': 473,
#  'missed': 474,
#  'sad': 475,
#  'missing': 476,
#  'lucky': 477,
#  '12hrs': 478,
#  'set': 479,
#  'pounds': 480,
#  'family': 481,
#  'cause': 482,
#  'second': 483,
#  'weeks': 484,
#  'gift': 485,
#  'eve': 486,
#  'far': 487,
#  'wid': 488,
#  'lei': 489,
#  'private': 490,
#  'neva': 491,
#  'lets': 492,
#  'top': 493,
#  'boytoy': 494,
#  'messages': 495,
#  'feeling': 496,
#  'happened': 497,
#  'search': 498,
#  'head': 499,
#  'date': 500,
#  'nope': 501,
#  'wants': 502,
#  'pics': 503,
#  'ard': 504,
#  'brother': 505,
#  'sea': 506,
#  'email': 507,
#  'drink': 508,
#  'frnd': 509,
#  'prob': 510,
#  'card': 511,
#  'trip': 512,
#  'de': 513,
#  'isnt': 514,
#  'true': 515,
#  'makes': 516,
#  'rite': 517,
#  'drive': 518,
#  'final': 519,
#  'å£100': 520,
#  'å£5000': 521,
#  'voucher': 522,
#  'happen': 523,
#  'bday': 524,
#  'å£500': 525,
#  'full': 526,
#  'break': 527,
#  'unsubscribe': 528,
#  'fast': 529,
#  'whatever': 530,
#  'phones': 531,
#  'choose': 532,
#  'games': 533,
#  'alone': 534,
#  'available': 535,
#  'old': 536,
#  'taking': 537,
#  'beautiful': 538,
#  'sleeping': 539,
#  'started': 540,
#  'fucking': 541,
#  'drop': 542,
#  'ring': 543,
#  'log': 544,
#  'post': 545,
#  'case': 546,
#  'took': 547,
#  'mobileupd8': 548,
#  'services': 549,
#  'lesson': 550,
#  'land': 551,
#  'lots': 552,
#  'visit': 553,
#  '750': 554,
#  'å£250': 555,
#  '100': 556,
#  'pobox': 557,
#  'coz': 558,
#  'vouchers': 559,
#  'tomo': 560,
#  'cum': 561,
#  'auction': 562,
#  'dating': 563,
#  '10': 564,
#  'treat': 565,
#  'sun': 566,
#  'walk': 567,
#  'statement': 568,
#  'expires': 569,
#  'talking': 570,
#  'mine': 571,
#  'open': 572,
#  'pic': 573,
#  'secret': 574,
#  'ltd': 575,
#  'least': 576,
#  '08000839402': 577,
#  'forget': 578,
#  'tho': 579,
#  'shop': 580,
#  'saturday': 581,
#  '12': 582,
#  'hard': 583,
#  'smoke': 584,
#  'youll': 585,
#  'yr': 586,
#  'finally': 587,
#  'kind': 588,
#  'credit': 589,
#  'hand': 590,
#  'invited': 591,
#  'listen': 592,
#  'type': 593,
#  'ha': 594,
#  'worth': 595,
#  'tscs': 596,
#  'charge': 597,
#  'finished': 598,
#  'parents': 599,
#  'welcome': 600,
#  'college': 601,
#  'used': 602,
#  'mates': 603,
#  'mum': 604,
#  'caller': 605,
#  'sister': 606,
#  'unredeemed': 607,
#  'identifier': 608,
#  'anytime': 609,
#  'wkly': 610,
#  'wil': 611,
#  'knw': 612,
#  'seen': 613,
#  'telling': 614,
#  'sis': 615,
#  'loving': 616,
#  'girls': 617,
#  'crazy': 618,
#  'mr': 619,
#  'touch': 620,
#  'enter': 621,
#  'anyone': 622,
#  'blue': 623,
#  'mrng': 624,
#  'thinks': 625,
#  'opt': 626,
#  'wasnt': 627,
#  'mayb': 628,
#  'mah': 629,
#  'motorola': 630,
#  'content': 631,
#  'area': 632,
#  'mate': 633,
#  'nt': 634,
#  'å£350': 635,
#  'takes': 636,
#  'mu': 637,
#  'winner': 638,
#  'txts': 639,
#  'ass': 640,
#  'camcorder': 641,
#  'questions': 642,
#  'youve': 643,
#  'eg': 644,
#  'smth': 645,
#  'company': 646,
#  'party': 647,
#  'delivery': 648,
#  'news': 649,
#  'askd': 650,
#  'cut': 651,
#  'fancy': 652,
#  'decided': 653,
#  'download': 654,
#  'chennai': 655,
#  'gd': 656,
#  'ten': 657,
#  'hungry': 658,
#  'pm': 659,
#  'awesome': 660,
#  '150pmsg': 661,
#  'player': 662,
#  'pub': 663,
#  'ni8': 664,
#  'needs': 665,
#  'bout': 666,
#  'unlimited': 667,
#  'almost': 668,
#  'rock': 669,
#  '10p': 670,
#  'fr': 671,
#  'etc': 672,
#  'picking': 673,
#  'reason': 674,
#  'bslvyl': 675,
#  '150': 676,
#  'angry': 677,
#  'hit': 678,
#  'earlier': 679,
#  'fri': 680,
#  'ago': 681,
#  'course': 682,
#  'frnds': 683,
#  'information': 684,
#  'surprise': 685,
#  'currently': 686,
#  'congratulations': 687,
#  'age': 688,
#  '8': 689,
#  'gas': 690,
#  'movie': 691,
#  '0800': 692,
#  'carlos': 693,
#  '08000930705': 694,
#  'point': 695,
#  'th': 696,
#  'yar': 697,
#  'wrong': 698,
#  'reading': 699,
#  'seeing': 700,
#  'dogging': 701,
#  'pretty': 702,
#  'direct': 703,
#  'sounds': 704,
#  'difficult': 705,
#  'friday': 706,
#  'side': 707,
#  'park': 708,
#  'march': 709,
#  'project': 710,
#  'within': 711,
#  'outside': 712,
#  'comes': 713,
#  'goodmorning': 714,
#  'b4': 715,
#  'operator': 716,
#  'gone': 717,
#  'national': 718,
#  'truth': 719,
#  'asap': 720,
#  'laugh': 721,
#  'bill': 722,
#  'complimentary': 723,
#  'wine': 724,
#  'charged': 725,
#  'slow': 726,
#  'sending': 727,
#  'asking': 728,
#  'numbers': 729,
#  'fantastic': 730,
#  'st': 731,
#  'eh': 732,
#  'across': 733,
#  'couple': 734,
#  'valued': 735,
#  '\x89û': 736,
#  '10pmin': 737,
#  'shower': 738,
#  'support': 739,
#  'hmm': 740,
#  'uncle': 741,
#  'checking': 742,
#  'swing': 743,
#  'msgs': 744,
#  'mm': 745,
#  'john': 746,
#  'match': 747,
#  'hospital': 748,
#  'wana': 749,
#  'hoping': 750,
#  'figure': 751,
#  'wats': 752,
#  'comp': 753,
#  'read': 754,
#  'light': 755,
#  'cheap': 756,
#  'exam': 757,
#  'txting': 758,
#  'sex': 759,
#  'heard': 760,
#  'orchard': 761,
#  '87066': 762,
#  'ipod': 763,
#  'ntt': 764,
#  'cs': 765,
#  'semester': 766,
#  'darlin': 767,
#  'computer': 768,
#  'gal': 769,
#  'hmv': 770,
#  'entered': 771,
#  'correct': 772,
#  'knew': 773,
#  'felt': 774,
#  'wit': 775,
#  'w': 776,
#  'empty': 777,
#  'meant': 778,
#  'lost': 779,
#  'extra': 780,
#  'frm': 781,
#  'slowly': 782,
#  'ex': 783,
#  '2003': 784,
#  '800': 785,
#  'link': 786,
#  'ldn': 787,
#  'whos': 788,
#  'luck': 789,
#  'quiz': 790,
#  'sony': 791,
#  'rs': 792,
#  'monday': 793,
#  'using': 794,
#  'christmas': 795,
#  'loads': 796,
#  'charity': 797,
#  'lovely': 798,
#  'hold': 799,
#  'confirm': 800,
#  'leaves': 801,
#  'worries': 802,
#  'mobiles': 803,
#  'laptop': 804,
#  'uk': 805,
#  'drugs': 806,
#  'comin': 807,
#  'oops': 808,
#  'pete': 809,
#  'darren': 810,
#  'months': 811,
#  'paper': 812,
#  'yep': 813,
#  'sell': 814,
#  'move': 815,
#  'buying': 816,
#  'convey': 817,
#  'ending': 818,
#  'doctor': 819,
#  'india': 820,
#  'jay': 821,
#  'hee': 822,
#  'poor': 823,
#  'wap': 824,
#  'mom': 825,
#  'sound': 826,
#  'del': 827,
#  'terms': 828,
#  'gods': 829,
#  'snow': 830,
#  'whole': 831,
#  'knows': 832,
#  'rply': 833,
#  'england': 834,
#  'flag': 835,
#  'gym': 836,
#  'info': 837,
#  'bath': 838,
#  'hmmm': 839,
#  'usf': 840,
#  'wishing': 841,
#  'bank': 842,
#  'summer': 843,
#  'dreams': 844,
#  'dnt': 845,
#  'hell': 846,
#  'muz': 847,
#  'rental': 848,
#  'decide': 849,
#  'wondering': 850,
#  'gets': 851,
#  'gotta': 852,
#  'moms': 853,
#  'bathe': 854,
#  'supposed': 855,
#  'met': 856,
#  'ho': 857,
#  'wonderful': 858,
#  'rain': 859,
#  'pass': 860,
#  'colleagues': 861,
#  '\x89ûò': 862,
#  'loan': 863,
#  'offers': 864,
#  'lover': 865,
#  'std': 866,
#  'em': 867,
#  'energy': 868,
#  'booked': 869,
#  'grins': 870,
#  'cute': 871,
#  'style': 872,
#  'sunshine': 873,
#  'dvd': 874,
#  'rest': 875,
#  'study': 876,
#  'sick': 877,
#  'others': 878,
#  'song': 879,
#  'xx': 880,
#  'police': 881,
#  'bcoz': 882,
#  'replying': 883,
#  'admirer': 884,
#  'thinkin': 885,
#  'oredi': 886,
#  'sort': 887,
#  'wishes': 888,
#  'accept': 889,
#  'user': 890,
#  'awaiting': 891,
#  'brings': 892,
#  'woke': 893,
#  'understand': 894,
#  'small': 895,
#  'kinda': 896,
#  'mode': 897,
#  'somebody': 898,
#  'ends': 899,
#  'wwwgetzedcouk': 900,
#  'optout': 901,
#  'feels': 902,
#  'urself': 903,
#  'chikku': 904,
#  'remove': 905,
#  'less': 906,
#  '87077': 907,
#  'tonite': 908,
#  'tired': 909,
#  'uks': 910,
#  'die': 911,
#  'different': 912,
#  'whenever': 913,
#  'sim': 914,
#  'wonder': 915,
#  'nah': 916,
#  'film': 917,
#  'father': 918,
#  'happiness': 919,
#  'youd': 920,
#  'kids': 921,
#  'store': 922,
#  'short': 923,
#  'sometimes': 924,
#  'safe': 925,
#  'ans': 926,
#  'unless': 927,
#  'catch': 928,
#  'facebook': 929,
#  'p': 930,
#  'pizza': 931,
#  'voice': 932,
#  'crave': 933,
#  'sofa': 934,
#  'silent': 935,
#  'lect': 936,
#  'å£200': 937,
#  'xy': 938,
#  'near': 939,
#  'freemsg': 940,
#  'savamob': 941,
#  'wow': 942,
#  'rent': 943,
#  'doin': 944,
#  'valentine': 945,
#  'spend': 946,
#  'door': 947,
#  'tel': 948,
#  'moment': 949,
#  'gave': 950,
#  'add': 951,
#  'abiola': 952,
#  'boss': 953,
#  'credits': 954,
#  'lessons': 955,
#  '3g': 956,
#  'country': 957,
#  'sense': 958,
#  'loves': 959,
#  'nyt': 960,
#  'starts': 961,
#  'loved': 962,
#  'ones': 963,
#  'shuhui': 964,
#  'water': 965,
#  'btnationalrate': 966,
#  'rather': 967,
#  'present': 968,
#  'slave': 969,
#  'merry': 970,
#  '08712460324': 971,
#  'bb': 972,
#  'especially': 973,
#  'polys': 974,
#  'anymore': 975,
#  'cup': 976,
#  'sale': 977,
#  'omg': 978,
#  'registered': 979,
#  'share': 980,
#  'plans': 981,
#  'murdered': 982,
#  'murderer': 983,
#  'immediately': 984,
#  'wheres': 985,
#  'movies': 986,
#  'sit': 987,
#  'clean': 988,
#  'reference': 989,
#  'sucks': 990,
#  'honey': 991,
#  'training': 992,
#  'complete': 993,
#  'stupid': 994,
#  'single': 995,
#  'wun': 996,
#  'aint': 997,
#  'onto': 998,
#  'reward': 999,
#  'towards': 1000,
#  ...}

# %%
# train sequences

X_train_sequences = tokenizer.texts_to_sequences(X_train_temp)
X_train = pad_sequences(X_train_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_train.shape
# Out:
# (4457, 80)

# %%
# test sequences

X_test_sequences = tokenizer.texts_to_sequences(X_test_temp)
X_test = pad_sequences(X_test_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_test.shape
# Out:
# (1115, 80)

# %%
# model

model = Sequential()
model.add(Embedding(len(words_statistic), 32, input_length = max_token))
model.add(LSTM(64, dropout = .1))
model.add(Dense(1, activation = "sigmoid"))

optimizer = Adam(lr=7e-5)

model.compile(loss = "binary_crossentropy", optimizer = optimizer, metrics = ["accuracy"])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 80, 32)            301792
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 326,689
# Trainable params: 326,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(X_train, y_train, epochs = 20, validation_data=(X_test, y_test))
# Out:
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.6328 - acc: 0.8503 - val_loss: 0.4481 - val_acc: 0.8664
# Epoch 2/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.3976 - acc: 0.8658 - val_loss: 0.3924 - val_acc: 0.8664
# Epoch 3/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.3945 - acc: 0.8658 - val_loss: 0.3922 - val_acc: 0.8664
# Epoch 4/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.3929 - acc: 0.8658 - val_loss: 0.3932 - val_acc: 0.8664
# Epoch 5/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.3935 - acc: 0.8658 - val_loss: 0.3909 - val_acc: 0.8664
# Epoch 6/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.3930 - acc: 0.8658 - val_loss: 0.3905 - val_acc: 0.8664
# Epoch 7/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.3923 - acc: 0.8658 - val_loss: 0.3927 - val_acc: 0.8664
# Epoch 8/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.3901 - acc: 0.8658 - val_loss: 0.3885 - val_acc: 0.8664
# Epoch 9/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.3883 - acc: 0.8658 - val_loss: 0.3798 - val_acc: 0.8664
# Epoch 10/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.3754 - acc: 0.8658 - val_loss: 0.3749 - val_acc: 0.8664
# Epoch 11/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.3040 - acc: 0.8658 - val_loss: 0.2116 - val_acc: 0.8807
# Epoch 12/20
# 4457/4457 [==============================] - 17s 4ms/step - loss: 0.1901 - acc: 0.9399 - val_loss: 0.1891 - val_acc: 0.9507
# Epoch 13/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1839 - acc: 0.9441 - val_loss: 0.1838 - val_acc: 0.9498
# Epoch 14/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1708 - acc: 0.9500 - val_loss: 0.1834 - val_acc: 0.9489
# Epoch 15/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1763 - acc: 0.9412 - val_loss: 0.1945 - val_acc: 0.9327
# Epoch 16/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1677 - acc: 0.9468 - val_loss: 0.1858 - val_acc: 0.9471
# Epoch 17/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1669 - acc: 0.9545 - val_loss: 0.1837 - val_acc: 0.9480
# Epoch 18/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1712 - acc: 0.9470 - val_loss: 0.1771 - val_acc: 0.9480
# Epoch 19/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1604 - acc: 0.9527 - val_loss: 0.1826 - val_acc: 0.9453
# Epoch 20/20
# 4457/4457 [==============================] - 16s 4ms/step - loss: 0.1600 - acc: 0.9542 - val_loss: 0.1797 - val_acc: 0.9471

# %%
# index = dict([(value, key) for (key, value) in word_index.items()])
# def get_original_text(text):
#     return "".join([index.get(i, "") for i in text])
