# %% [markdown]
# # Installation

# %%
# !pip install keras

# %%
# !pip install collection

# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
import string
# import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense

# %% [markdown]
# # Implementation

# %%
# read data

data = pd.read_csv("spam.csv", encoding = "latin-1", usecols = [0, 1], header = None)

# %%
# rename header

data.iloc[0][0] = "tags"
data.iloc[0][1] = "text"
header = data.iloc[0]
data = data[1:]
data = data.rename(columns = header)

# %%
# remove punctuation

def remove_punct(text):
    text_only = ''.join([char for char in text if char not in string.punctuation])
    return text_only



data["no_punct"] = data["text"].apply(lambda x: remove_punct(x))

# %%
# remove stopwords

stop_words = set(stopwords.words("English"))

def tokenize(text):
    return [word.lower() for word in text.split() if word.lower() not in stop_words]



data["tokens"] = data["no_punct"].apply(lambda x: tokenize(x))

# %%
# labels to int   spam = 1, ham = 0

def label_to_num(label):
    return 1 if label == "spam" else 0
data["labels"] = data["tags"].apply(lambda x: label_to_num(x))



data
# Out:
#       tags                                               text  \
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# 5      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham              Will Ì_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
#                                                no_punct  \
# 1     Go until jurong point crazy Available only in ...
# 2                               Ok lar Joking wif u oni
# 3     Free entry in 2 a wkly comp to win FA Cup fina...
# 4           U dun say so early hor U c already then say
# 5     Nah I dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5568  This is the 2nd time we have tried 2 contact u...
# 5569                Will Ì b going to esplanade fr home
# 5570  Pity  was in mood for that Soany other suggest...
# 5571  The guy did some bitching but I acted like id ...
# 5572                          Rofl Its true to its name
#
#                                                  tokens  labels
# 1     [go, jurong, point, crazy, available, bugis, n...       0
# 2                        [ok, lar, joking, wif, u, oni]       0
# 3     [free, entry, 2, wkly, comp, win, fa, cup, fin...       1
# 4         [u, dun, say, early, hor, u, c, already, say]       0
# 5     [nah, dont, think, goes, usf, lives, around, t...       0
# ...                                                 ...     ...
# 5568  [2nd, time, tried, 2, contact, u, u, å£750, po...       1
# 5569                 [ì, b, going, esplanade, fr, home]       0
# 5570                   [pity, mood, soany, suggestions]       0
# 5571  [guy, bitching, acted, like, id, interested, b...       0
# 5572                                 [rofl, true, name]       0
#
# [5572 rows x 5 columns]

# %%
# count unique words

def count_words(textset):
    count = Counter()
    max_tkn = 0
    for row in textset:
        i = 0
        for token in row:
            count[token] += 1
            i += 1
        max_tkn = i if i > max_tkn else max_tkn
    return count, max_tkn

words_statistic, max_token = count_words(data["tokens"])
print(max_token)
print(len(words_statistic))
words_statistic
# Out:
# 80
# 9431
# Counter({'go': 278,
#          'jurong': 1,
#          'point': 13,
#          'crazy': 15,
#          'available': 16,
#          'bugis': 7,
#          'n': 143,
#          'great': 111,
#          'world': 33,
#          'la': 7,
#          'e': 84,
#          'buffet': 2,
#          'cine': 7,
#          'got': 238,
#          'amore': 1,
#          'wat': 96,
#          'ok': 277,
#          'lar': 38,
#          'joking': 6,
#          'wif': 27,
#          'u': 1119,
#          'oni': 4,
#          'free': 275,
#          'entry': 26,
#          '2': 478,
#          'wkly': 14,
#          'comp': 11,
#          'win': 71,
#          'fa': 4,
#          'cup': 8,
#          'final': 18,
#          'tkts': 4,
#          '21st': 3,
#          'may': 46,
#          '2005': 3,
#          'text': 188,
#          '87121': 4,
#          'receive': 38,
#          'questionstd': 2,
#          'txt': 163,
#          'ratetcs': 2,
#          'apply': 31,
#          '08452810075over18s': 2,
#          'dun': 55,
#          'say': 91,
#          'early': 33,
#          'hor': 2,
#          'c': 79,
#          'already': 90,
#          'nah': 10,
#          'dont': 279,
#          'think': 132,
#          'goes': 26,
#          'usf': 11,
#          'lives': 4,
#          'around': 61,
#          'though': 26,
#          'freemsg': 12,
#          'hey': 111,
#          'darling': 5,
#          '3': 66,
#          'weeks': 19,
#          'word': 34,
#          'back': 152,
#          'id': 32,
#          'like': 242,
#          'fun': 31,
#          'still': 153,
#          'tb': 4,
#          'xxx': 32,
#          'std': 9,
#          'chgs': 1,
#          'send': 190,
#          'å£150': 27,
#          'rcv': 2,
#          'even': 61,
#          'brother': 19,
#          'speak': 33,
#          'treat': 16,
#          'aids': 1,
#          'patent': 1,
#          'per': 58,
#          'request': 8,
#          'melle': 6,
#          'oru': 4,
#          'minnaminunginte': 3,
#          'nurungu': 3,
#          'vettam': 3,
#          'set': 20,
#          'callertune': 10,
#          'callers': 5,
#          'press': 10,
#          '9': 26,
#          'copy': 9,
#          'friends': 58,
#          'winner': 16,
#          'valued': 13,
#          'network': 29,
#          'customer': 58,
#          'selected': 29,
#          'receivea': 2,
#          'å£900': 7,
#          'prize': 92,
#          'reward': 10,
#          'claim': 113,
#          'call': 576,
#          '09061701461': 2,
#          'code': 30,
#          'kl341': 2,
#          'valid': 23,
#          '12': 14,
#          'hours': 21,
#          'mobile': 138,
#          '11': 9,
#          'months': 13,
#          'r': 153,
#          'entitled': 8,
#          'update': 24,
#          'latest': 39,
#          'colour': 21,
#          'mobiles': 12,
#          'camera': 36,
#          'co': 7,
#          '08002986030': 2,
#          'im': 462,
#          'gonna': 58,
#          'home': 162,
#          'soon': 59,
#          'want': 192,
#          'talk': 45,
#          'stuff': 43,
#          'anymore': 8,
#          'tonight': 59,
#          'k': 71,
#          'ive': 74,
#          'cried': 1,
#          'enough': 29,
#          'today': 141,
#          'six': 4,
#          'chances': 2,
#          'cash': 74,
#          '100': 16,
#          '20000': 2,
#          'pounds': 19,
#          'csh11': 2,
#          '87575': 4,
#          'cost': 33,
#          '150pday': 2,
#          '6days': 2,
#          '16': 50,
#          'tsandcs': 2,
#          'reply': 144,
#          'hl': 6,
#          '4': 287,
#          'info': 10,
#          'urgent': 65,
#          '1': 82,
#          'week': 115,
#          'membership': 3,
#          'å£100000': 2,
#          'jackpot': 2,
#          '81010': 2,
#          'tc': 23,
#          'wwwdbuknet': 2,
#          'lccltd': 2,
#          'pobox': 16,
#          '4403ldnw1a7rw18': 2,
#          'searching': 5,
#          'right': 92,
#          'words': 22,
#          'thank': 28,
#          'breather': 1,
#          'promise': 9,
#          'wont': 54,
#          'take': 126,
#          'help': 55,
#          'granted': 1,
#          'fulfil': 1,
#          'wonderful': 15,
#          'blessing': 2,
#          'times': 24,
#          'date': 18,
#          'sunday': 8,
#          'xxxmobilemovieclub': 1,
#          'use': 44,
#          'credit': 14,
#          'click': 7,
#          'wap': 10,
#          'link': 10,
#          'next': 62,
#          'message': 83,
#          'httpwap': 1,
#          'xxxmobilemovieclubcomnqjkgighjjgcbl': 1,
#          'oh': 112,
#          'kim': 1,
#          'watching': 34,
#          'eh': 12,
#          'remember': 31,
#          'spell': 3,
#          'name': 47,
#          'yes': 86,
#          'v': 52,
#          'naughty': 6,
#          'make': 101,
#          'wet': 5,
#          'fine': 45,
#          'thatåõs': 4,
#          'way': 101,
#          'feel': 62,
#          'gota': 1,
#          'b': 65,
#          'england': 10,
#          'macedonia': 1,
#          'miss': 76,
#          'goalsteam': 1,
#          'news': 17,
#          'ur': 384,
#          'national': 12,
#          'team': 6,
#          '87077': 8,
#          'eg': 12,
#          'trywales': 1,
#          'scotland': 3,
#          '4txtì¼120': 1,
#          'poboxox36504w45wq': 1,
#          'seriously': 9,
#          'i\x89û÷m': 5,
#          'going': 171,
#          'try': 48,
#          'ha': 16,
#          'ì': 117,
#          'pay': 31,
#          'first': 62,
#          'da': 131,
#          'stock': 5,
#          'comin': 11,
#          'aft': 19,
#          'finish': 42,
#          'lunch': 45,
#          'str': 4,
#          'lor': 160,
#          'ard': 21,
#          'smth': 16,
#          'ffffffffff': 1,
#          'alright': 23,
#          'meet': 78,
#          'sooner': 4,
#          'forced': 1,
#          'eat': 38,
#          'slice': 2,
#          'really': 86,
#          'hungry': 14,
#          'tho': 17,
#          'sucks': 7,
#          'mark': 8,
#          'getting': 50,
#          'worried': 9,
#          'knows': 10,
#          'sick': 9,
#          'turn': 4,
#          'pizza': 8,
#          'lol': 73,
#          'always': 56,
#          'convincing': 1,
#          'catch': 9,
#          'bus': 29,
#          'frying': 3,
#          'egg': 4,
#          'tea': 6,
#          'eating': 7,
#          'moms': 9,
#          'left': 30,
#          'dinner': 35,
#          'love': 195,
#          'amp': 82,
#          'packing': 1,
#          'car': 39,
#          'ill': 237,
#          'let': 70,
#          'know': 257,
#          'theres': 29,
#          'room': 34,
#          'ahhh': 1,
#          'work': 99,
#          'vaguely': 1,
#          'wait': 59,
#          'thats': 94,
#          'clear': 3,
#          'sure': 71,
#          'sarcastic': 2,
#          'x': 49,
#          'doesnt': 26,
#          'live': 46,
#          'us': 63,
#          'yeah': 86,
#          'apologetic': 1,
#          'fallen': 1,
#          'actin': 1,
#          'spoilt': 1,
#          'child': 3,
#          'caught': 3,
#          'till': 24,
#          'badly': 1,
#          'cheers': 8,
#          'tell': 137,
#          'anything': 73,
#          'fear': 3,
#          'fainting': 1,
#          'housework': 1,
#          'quick': 8,
#          'cuppa': 1,
#          'thanks': 74,
#          'subscription': 4,
#          'ringtone': 26,
#          'uk': 16,
#          'charged': 11,
#          'å£5month': 1,
#          'please': 128,
#          'confirm': 11,
#          'replying': 8,
#          'yup': 43,
#          'look': 31,
#          'timings': 1,
#          'msg': 81,
#          'xuhui': 3,
#          'learn': 7,
#          '2nd': 30,
#          'lesson': 17,
#          '8am': 2,
#          'oops': 10,
#          'roommates': 5,
#          'done': 49,
#          'see': 156,
#          'letter': 4,
#          'decide': 9,
#          'hello': 49,
#          'hows': 44,
#          'saturday': 16,
#          'texting': 6,
#          'youd': 8,
#          'decided': 16,
#          'tomo': 17,
#          'trying': 43,
#          'invite': 3,
#          'pls': 109,
#          'ahead': 7,
#          'watts': 1,
#          'wanted': 26,
#          'weekend': 30,
#          'abiola': 11,
#          'forget': 18,
#          'need': 166,
#          'crave': 11,
#          'sweet': 33,
#          'arabian': 1,
#          'steed': 1,
#          'mmmmmm': 2,
#          'yummy': 3,
#          '07732584351': 1,
#          'rodger': 1,
#          'burns': 2,
#          'tried': 22,
#          'sms': 42,
#          'nokia': 68,
#          'camcorder': 15,
#          '08000930705': 16,
#          'delivery': 22,
#          'tomorrow': 90,
#          'seeing': 14,
#          'hope': 103,
#          'man': 45,
#          'well': 133,
#          'endowed': 1,
#          'ltgt': 276,
#          'inches': 4,
#          'callsmessagesmissed': 3,
#          'calls': 24,
#          'didnt': 79,
#          'get': 386,
#          'hep': 1,
#          'immunisation': 1,
#          'nigeria': 8,
#          'fair': 3,
#          'hopefully': 5,
#          'tyler': 5,
#          'cant': 123,
#          'could': 60,
#          'maybe': 31,
#          'ask': 88,
#          'bit': 43,
#          'stubborn': 1,
#          'hospital': 10,
#          'kept': 7,
#          'telling': 14,
#          'weak': 5,
#          'sucker': 1,
#          'hospitals': 2,
#          'suckers': 1,
#          'thinked': 1,
#          'time': 208,
#          'saw': 23,
#          'class': 45,
#          'gram': 3,
#          'usually': 6,
#          'runs': 3,
#          'half': 38,
#          'eighth': 2,
#          'smarter': 1,
#          'gets': 11,
#          'almost': 13,
#          'whole': 14,
#          'second': 18,
#          'fyi': 6,
#          'ride': 5,
#          'morning': 77,
#          'hes': 32,
#          'crashing': 1,
#          'place': 59,
#          'wow': 12,
#          'never': 43,
#          'realized': 3,
#          'embarassed': 4,
#          'accomodations': 1,
#          'thought': 47,
#          'liked': 7,
#          'since': 27,
#          'best': 44,
#          'seemed': 4,
#          'happy': 106,
#          'cave': 1,
#          'sorry': 156,
#          'give': 99,
#          'offered': 1,
#          'embarassing': 1,
#          'ac': 4,
#          'sptv': 2,
#          'new': 136,
#          'jersey': 1,
#          'devils': 1,
#          'detroit': 2,
#          'red': 5,
#          'wings': 1,
#          'play': 38,
#          'ice': 8,
#          'hockey': 2,
#          'correct': 12,
#          'incorrect': 1,
#          'end': 39,
#          'mallika': 1,
#          'sherawat': 1,
#          'yesterday': 23,
#          'find': 73,
#          'lturlgt': 3,
#          'congrats': 18,
#          'year': 50,
#          'special': 43,
#          'cinema': 8,
#          'pass': 11,
#          '09061209465': 3,
#          'suprman': 3,
#          'matrix3': 3,
#          'starwars3': 3,
#          'etc': 13,
#          'bx420ip45we': 3,
#          '150pm': 6,
#          'later': 134,
#          'meeting': 43,
#          'reached': 10,
#          'yesgauti': 1,
#          'sehwag': 1,
#          'odi': 2,
#          'series': 4,
#          'pick': 71,
#          'burger': 3,
#          'move': 11,
#          'pain': 24,
#          'killing': 2,
#          'good': 234,
#          'joke': 5,
#          'girls': 16,
#          'situation': 9,
#          'seekers': 1,
#          'part': 31,
#          'checking': 11,
#          'iq': 4,
#          'took': 19,
#          'forever': 9,
#          'come': 226,
#          'double': 22,
#          'check': 38,
#          'hair': 24,
#          'dresser': 3,
#          'said': 86,
#          'wun': 7,
#          'cut': 13,
#          'short': 9,
#          'nice': 57,
#          'pleased': 6,
#          'advise': 3,
#          'following': 7,
#          'recent': 3,
#          'review': 6,
#          'mob': 24,
#          'awarded': 38,
#          'å£1500': 4,
#          'bonus': 21,
#          '09066364589': 2,
#          'song': 12,
#          'dedicated': 2,
#          'day': 202,
#          'dedicate': 2,
#          'valuable': 4,
#          'frnds': 14,
#          'rply': 10,
#          'complimentary': 12,
#          'trip': 21,
#          'eurodisinc': 2,
#          'trav': 2,
#          'acoentry41': 2,
#          'å£1000': 35,
#          'dis': 30,
#          '186å£150morefrmmob': 2,
#          'shracomorsglsuplt10': 2,
#          'ls1': 2,
#          '3aj': 2,
#          'hear': 32,
#          'divorce': 2,
#          'barbie': 1,
#          'comes': 21,
#          'kens': 1,
#          'plane': 5,
#          'month': 30,
#          'wah': 4,
#          'lucky': 17,
#          'save': 10,
#          'money': 57,
#          'hee': 13,
#          'finished': 19,
#          'hi': 131,
#          'babe': 78,
#          'wanna': 38,
#          'something': 68,
#          'xx': 11,
#          'kkwhere': 2,
#          'youhow': 1,
#          'performed': 1,
#          'waiting': 53,
#          'machan': 4,
#          'cool': 41,
#          'gentleman': 3,
#          'dignity': 3,
#          'respect': 3,
#          'peoples': 1,
#          'much': 113,
#          'shy': 2,
#          'pa': 32,
#          'operate': 1,
#          'looking': 29,
#          'job': 43,
#          'tas': 1,
#          'earn': 2,
#          'ah': 30,
#          'stop': 150,
#          'urgnt': 5,
#          'real': 36,
#          'yo': 37,
#          'tickets': 10,
#          'one': 170,
#          'jacket': 2,
#          'used': 15,
#          'multis': 1,
#          'started': 18,
#          'requests': 3,
#          'came': 27,
#          'bed': 32,
#          'coins': 4,
#          'factory': 1,
#          'gotta': 12,
#          'nitros': 2,
#          'ela': 2,
#          'kanoil': 1,
#          'download': 13,
#          'wen': 24,
#          'don\x89û÷t': 6,
#          'stand': 7,
#          'close': 18,
#          'you\x89û÷ll': 1,
#          'another': 37,
#          'night': 113,
#          'spent': 8,
#          'late': 56,
#          'afternoon': 27,
#          'casualty': 1,
#          'means': 26,
#          'havent': 46,
#          'stuff42moro': 1,
#          'includes': 1,
#          'sheets': 3,
#          'smile': 44,
#          'pleasure': 7,
#          'trouble': 8,
#          'pours': 2,
#          'rain': 9,
#          'sum1': 3,
#          'hurts': 8,
#          'becoz': 4,
#          'someone': 59,
#          'loves': 8,
#          'smiling': 20,
#          'service': 59,
#          'representative': 10,
#          '0800': 13,
#          '169': 2,
#          '6031': 2,
#          '10am9pm': 2,
#          'guaranteed': 50,
#          'å£5000': 20,
#          'planning': 8,
#          'buy': 65,
#          'lido': 3,
#          '530': 7,
#          'show': 25,
#          'collected': 3,
#          'simply': 6,
#          'password': 7,
#          'mix': 3,
#          '85069': 2,
#          'verify': 3,
#          'usher': 2,
#          'britney': 2,
#          'fml': 4,
#          'telugu': 1,
#          'moviewat': 1,
#          'abt': 26,
#          'loads': 11,
#          'loans': 2,
#          'wk': 23,
#          'hols': 4,
#          'run': 23,
#          'forgot': 31,
#          'hairdressers': 1,
#          'appointment': 4,
#          'four': 3,
#          'shower': 11,
#          'beforehand': 1,
#          'cause': 18,
#          'prob': 16,
#          'ham': 3,
#          'nothing': 38,
#          'else': 24,
#          'okay': 26,
#          'price': 24,
#          'long': 42,
#          'legal': 4,
#          'ave': 8,
#          'ams': 1,
#          'gone': 15,
#          '4the': 1,
#          'driving': 22,
#          'test': 22,
#          'yet': 50,
#          'youre': 53,
#          'mean': 20,
#          'guess': 38,
#          'gave': 10,
#          'boston': 5,
#          'men': 9,
#          'changed': 7,
#          'search': 17,
#          'location': 2,
#          'nyc': 4,
#          'cuz': 7,
#          'signin': 1,
#          'page': 7,
#          'says': 27,
#          'umma': 7,
#          'life': 77,
#          'vava': 3,
#          'lot': 34,
#          'dear': 110,
#          'wishes': 8,
#          'birthday': 36,
#          'making': 23,
#          'truly': 5,
#          'memorable': 1,
#          'aight': 33,
#          'hit': 14,
#          'would': 76,
#          'ip': 1,
#          'address': 21,
#          'considering': 4,
#          'computer': 12,
#          'isnt': 17,
#          'minecraft': 1,
#          'server': 1,
#          'grumpy': 1,
#          'old': 20,
#          'people': 50,
#          'mom': 12,
#          'better': 42,
#          'lying': 1,
#          'jokes': 5,
#          'worry': 22,
#          'busy': 19,
#          'plural': 1,
#          'noun': 2,
#          'research': 4,
#          'dinnermsg': 1,
#          'cos': 76,
#          'things': 53,
#          'scared': 5,
#          'mah': 13,
#          'loud': 3,
#          'gent': 2,
#          'contact': 68,
#          'last': 78,
#          'weekends': 10,
#          'draw': 43,
#          'shows': 36,
#          '09064012160': 2,
#          'k52': 3,
#          '12hrs': 17,
#          '150ppm': 34,
#          'wa': 3,
#          'openin': 1,
#          'sentence': 3,
#          'formal': 1,
#          'anyway': 27,
#          'juz': 25,
#          'tt': 4,
#          'eatin': 7,
#          'puttin': 2,
#          'weighthaha': 1,
#          'anythin': 3,
#          'happened': 16,
#          'entered': 11,
#          'cabin': 5,
#          'bday': 15,
#          'boss': 9,
#          'felt': 13,
#          'askd': 12,
#          'invited': 13,
#          'apartment': 8,
#          'went': 61,
#          'specially': 9,
#          'holiday': 44,
#          'flights': 6,
#          'inc': 8,
#          'operator': 15,
#          '0871277810910pmin': 1,
#          '18': 43,
#          'goodo': 2,
#          'must': 27,
#          'friday': 14,
#          'eggpotato': 1,
#          'ratio': 1,
#          'tortilla': 2,
#          'needed': 3,
#          'hmmmy': 1,
#          'uncle': 12,
#          'informed': 5,
#          'paying': 8,
#          'school': 27,
#          'directly': 6,
#          'food': 23,
#          'private': 19,
#          '2004': 8,
#          'account': 39,
#          'statement': 17,
#          '07742676969': 2,
#          '786': 4,
#          'unredeemed': 16,
#          'points': 20,
#          '08719180248': 2,
#          'identifier': 16,
#          '45239': 3,
#          'expires': 17,
#          'å£2000': 31,
#          'caller': 13,
#          '5903': 1,
#          'landline': 34,
#          '09064019788': 1,
#          'box42wr29c': 1,
#          'applespairsall': 1,
#          'malarky': 1,
#          'todays': 28,
#          'voda': 5,
#          'numbers': 13,
#          'ending': 9,
#          '7548': 1,
#          '350': 2,
#          'award': 29,
#          'match': 11,
#          '08712300220': 6,
#          'quoting': 5,
#          '4041': 1,
#          'standard': 6,
#          'rates': 10,
#          'app': 6,
#          'sao': 1,
#          'mu': 14,
#          'ìï': 52,
#          'predict': 1,
#          'ìll': 2,
#          'buying': 9,
#          'knowyetunde': 1,
#          'hasnt': 5,
#          'sent': 68,
#          'bother': 7,
#          'sending': 12,
#          'involve': 1,
#          'shouldnt': 5,
#          'imposed': 1,
#          'apologise': 3,
#          'girl': 34,
#          'del': 10,
#          'bak': 8,
#          'sum': 2,
#          'lucyxx': 1,
#          'kkhow': 4,
#          'tmorrowpls': 1,
#          'accomodate': 1,
#          'answer': 22,
#          'question': 19,
#          'sunshine': 9,
#          'quiz': 13,
#          'q': 6,
#          'top': 22,
#          'sony': 9,
#          'dvd': 8,
#          'player': 14,
#          'country': 7,
#          'algarve': 2,
#          'ansr': 4,
#          '82277': 5,
#          'sptyrone': 4,
#          'laid': 4,
#          'dogging': 11,
#          'locations': 5,
#          'direct': 12,
#          'join': 27,
#          'uks': 10,
#          'largest': 4,
#          'bt': 23,
#          'txting': 11,
#          'gravel': 1,
#          '69888': 2,
#          'nt': 15,
#          'ec2a': 4,
#          '31pmsg150p': 2,
#          'haf': 23,
#          'msn': 2,
#          'yijuehotmailcom': 1,
#          'rooms': 5,
#          'befor': 4,
#          'activities': 4,
#          'youll': 14,
#          'msgs': 13,
#          'chat': 56,
#          'svc': 1,
#          'hardcore': 3,
#          'services': 18,
#          '69988': 1,
#          'age': 13,
#          'yr': 14,
#          'lazy': 9,
#          'type': 15,
#          'lect': 9,
#          'pouch': 2,
#          'sir': 34,
#          'mail': 24,
#          'swt': 2,
#          'nver': 1,
#          'tired': 12,
#          'little': 30,
#          'lovable': 10,
#          'persons': 7,
#          'cozsomtimes': 1,
#          'occupy': 2,
#          'biggest': 4,
#          'hearts': 1,
#          'gud': 53,
#          'ni8': 12,
#          'open': 17,
#          'ya': 56,
#          'dot': 3,
#          'whats': 33,
#          'staff': 2,
#          'taking': 18,
#          'replied': 6,
#          'randy': 2,
#          'sexy': 27,
#          'female': 3,
#          'local': 6,
#          'luv': 34,
#          'netcollex': 4,
#          'ltd': 15,
#          '08700621170150p': 2,
#          'ummmawill': 1,
#          'inour': 1,
#          'begin': 5,
#          'qatar': 4,
#          'pray': 8,
#          'hard': 16,
#          'ki': 6,
#          'deleted': 4,
#          'sindu': 1,
#          'birla': 3,
#          'soft': 3,
#          'wine': 11,
#          'flowing': 2,
#          'nevering': 1,
#          'thk': 50,
#          'plaza': 2,
#          'typical': 1,
#          'everywhere': 2,
#          'dirt': 1,
#          'floor': 3,
#          'windows': 2,
#          'shirt': 4,
#          'sometimes': 8,
#          'mouth': 2,
#          'dream': 10,
#          'without': 28,
#          'chores': 1,
#          'joy': 4,
#          'lots': 17,
#          'tv': 28,
#          'exist': 1,
#          'hail': 1,
#          'mist': 1,
#          'become': 6,
#          'aaooooright': 1,
#          'leaving': 19,
#          'house': 36,
#          'interview': 4,
#          'boy': 30,
#          'meare': 1,
#          'missing': 27,
#          'annoncement': 1,
#          'years': 25,
#          '07046744435': 1,
#          'arrange': 6,
#          '0871277810810': 2,
#          'keep': 68,
#          'safe': 11,
#          'envy': 1,
#          'everyone': 18,
#          'sees': 1,
#          'parentsi': 1,
#          'hand': 15,
#          'excited': 1,
#          'spend': 10,
#          'bootydelious': 1,
#          '32f': 1,
#          'inviting': 6,
#          'friend': 47,
#          'yes434': 1,
#          'no434': 1,
#          'wwwsmsacubootydelious': 1,
#          'frnd': 16,
#          '62468': 6,
#          'bangbabes': 1,
#          'order': 21,
#          'content': 15,
#          'goto': 8,
#          'bangb': 1,
#          'internetservice': 1,
#          'menu': 7,
#          'cultures': 1,
#          'module': 2,
#          '09061701939': 1,
#          's89': 1,
#          'avoid': 2,
#          'missunderstding': 1,
#          'wit': 15,
#          'beloved': 2,
#          'ones': 10,
#          'escape': 4,
#          'fancy': 14,
#          'bridge': 1,
#          'needs': 16,
#          'lager': 1,
#          'completely': 9,
#          'formclark': 2,
#          'also': 71,
#          'utter': 2,
#          'waste': 7,
#          'axis': 1,
#          'bank': 14,
#          'hmmm': 9,
#          'hop': 7,
#          'muz': 11,
#          'discuss': 5,
#          'liao': 35,
#          'coming': 50,
#          'bloody': 4,
#          'hell': 12,
#          'believe': 20,
#          'surname': 1,
#          ...})

# %%
# training and testing dataset

X_train_temp, X_test_temp, y_train, y_test = train_test_split(data["tokens"], data["labels"], test_size = 0.2, shuffle = True, random_state = 0, stratify = data["labels"])

# %%
# tokenizer

tokenizer = Tokenizer(num_words = max_token)
tokenizer.fit_on_texts(X_train_temp)
word_index = tokenizer.word_index

# %%
# train sequences

X_train_sequences = tokenizer.texts_to_sequences(X_train_temp)
X_train = pad_sequences(X_train_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_train.shape
# Out:
# (4457, 80)

# %%
# test sequences

X_test_sequences = tokenizer.texts_to_sequences(X_test_temp)
X_test = pad_sequences(X_test_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_test.shape
# Out:
# (1115, 80)

# %%
# model

model = Sequential()
model.add(Embedding(len(words_statistic), 32, input_length = max_token))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 80, 32)            301792
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 76, 128)           20608
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 323,701
# Trainable params: 323,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(X_train, y_train, epochs = 10, validation_data=(X_test, y_test), batch_size=10)
# Out:
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 4457/4457 [==============================] - 4s 992us/step - loss: 0.2434 - acc: 0.9129 - val_loss: 0.1798 - val_acc: 0.9453
# Epoch 2/10
# 4457/4457 [==============================] - 2s 341us/step - loss: 0.1346 - acc: 0.9587 - val_loss: 0.1635 - val_acc: 0.9435
# Epoch 3/10
# 4457/4457 [==============================] - 2s 339us/step - loss: 0.1228 - acc: 0.9583 - val_loss: 0.1413 - val_acc: 0.9552
# Epoch 4/10
# 4457/4457 [==============================] - 2s 345us/step - loss: 0.1154 - acc: 0.9610 - val_loss: 0.1380 - val_acc: 0.9587
# Epoch 5/10
# 4457/4457 [==============================] - 2s 348us/step - loss: 0.1121 - acc: 0.9634 - val_loss: 0.1400 - val_acc: 0.9552
# Epoch 6/10
# 4457/4457 [==============================] - 2s 350us/step - loss: 0.1057 - acc: 0.9675 - val_loss: 0.1405 - val_acc: 0.9534
# Epoch 7/10
# 4457/4457 [==============================] - 2s 352us/step - loss: 0.1024 - acc: 0.9679 - val_loss: 0.1444 - val_acc: 0.9641
# Epoch 8/10
# 4457/4457 [==============================] - 2s 349us/step - loss: 0.0978 - acc: 0.9686 - val_loss: 0.1474 - val_acc: 0.9578
# Epoch 9/10
# 4457/4457 [==============================] - 2s 356us/step - loss: 0.0925 - acc: 0.9726 - val_loss: 0.1512 - val_acc: 0.9498
# Epoch 10/10
# 4457/4457 [==============================] - 2s 351us/step - loss: 0.0879 - acc: 0.9731 - val_loss: 0.1498 - val_acc: 0.9614
