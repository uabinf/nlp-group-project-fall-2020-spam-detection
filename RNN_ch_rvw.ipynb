# %% [markdown]
# # Installation

# %%
# !pip install collection
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting collection
#   Downloading collection-0.1.6.tar.gz (5.0 kB)
# Building wheels for collected packages: collection
#   Building wheel for collection (setup.py) ... done
#   Created wheel for collection: filename=collection-0.1.6-py3-none-any.whl size=5114 sha256=9833c237870afd4fd0893b2775d5e55dddd23bbc4b3318fb225c6233c6158d84
#   Stored in directory: /home/chunyi/.cache/pip/wheels/3b/e0/fe/8e68dd2243f4e4741fd3950f2dbeb2fdf4b604767fde39598f
# Successfully built collection
# Installing collected packages: collection
# Successfully installed collection-0.1.6

# %%
# !pip install jieba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      |████████████████████████████████| 19.2 MB 117 kB/s eta 0:00:01
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314478 sha256=fdd27b992ab37ad4693023b50bc3c020b1891f7b0e79d9119f92bc8149883677
#   Stored in directory: /home/chunyi/.cache/pip/wheels/ca/38/d8/dfdfe73bec1d12026b30cb7ce8da650f3f0ea2cf155ea018ae
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
# !pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: h5py in /data/rc/apps/rc/software/Anaconda3/2020.07/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /data/rc/apps/rc/software/Anaconda3/2020.07/lib/python3.8/site-packages (from keras) (1.5.0)
# Requirement already satisfied: numpy>=1.9.1 in /data/rc/apps/rc/software/Anaconda3/2020.07/lib/python3.8/site-packages (from keras) (1.18.5)
# Requirement already satisfied: pyyaml in /data/rc/apps/rc/software/Anaconda3/2020.07/lib/python3.8/site-packages (from keras) (5.3.1)
# Requirement already satisfied: six in /data/rc/apps/rc/software/Anaconda3/2020.07/lib/python3.8/site-packages (from h5py->keras) (1.15.0)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd
import string
import jieba
# import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from collections import Counter
from sklearn.model_selection import train_test_split

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.initializers import Constant
from keras.optimizers import Adam

# %% [markdown]
# # Implementation

# %%
# read data

document = pd.read_csv("ICDM_REVIEWS_TO_RELEASE_encoding=gb18030.csv", encoding = "GB18030", header = None)
document
# Out:
#                0      1         2       3     4  \
# 0      review_id  label      user      ip  star
# 1        REVIEW0      +     USER1     IP1     5
# 2        REVIEW1      -     USER2     IP2     4
# 3        REVIEW2      +     USER3     IP3     5
# 4        REVIEW3      -     USER4     IP4     5
# ...          ...    ...       ...     ...   ...
# 9761  REVIEW9760      +  USER9063  IP4317     5
# 9762  REVIEW9761      -  USER9064    IP25     4
# 9763  REVIEW9762      +  USER9065  IP1687     5
# 9764  REVIEW9763      -  USER9066  IP5535     5
# 9765  REVIEW9764      +  USER9067  IP1859     5
#
#                                                       5
# 0                                                  text
# 1     他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2     鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3     跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4     我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# ...                                                 ...
# 9761  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
# [9766 rows x 6 columns]

# %%
# rename header

header = document.iloc[0]
document = document[1:]
document = document.rename(columns = header)
data = pd.DataFrame()
data["label"] = document["label"].copy()
data["text"] = document["text"].copy()

# %%
data
# Out:
#      label                                               text
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
# [9765 rows x 2 columns]

# %%
# remove punctuation, stopwords
# source of Chinese punct: https://github.com/tsroten/zhon/blob/develop/docs/index.rst

def tokenize(text):
    """Given a sentence remove its punctuation and stop words"""
    
    with open("stopwords.txt", 'r',encoding='GB18030') as f:
        stopwords = f.read().splitlines()
    
    l=list()
    seg_list = jieba.cut(text, cut_all=False)
    for seg in seg_list:
        if seg not in stopwords:
            l.append(seg)
    
    cleaned_text = [w for w in l if w not in stopwords] # removing stop-words
    return cleaned_text # using the first 10 tokens only

# %%
data["texts"] = data["text"].apply(tokenize)
data
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /scratch/local/jieba.cache
# Loading model cost 0.736 seconds.
# Prefix dict has been built successfully.
#      label                                               text  \
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
#                                                   texts
# 1     [他家, 面, 嚼, 劲, 牛肉汤, 味道, 服务员, 服务, 特别, 服务员, 顾存芳, ...
# 2     [鲜榨, 果汁, 不错, 水果, 新鲜, 口感, 小妹妹, 态度, 环境, 专家, 告诉, ...
# 3     [老婆, 二人, 世界, 就定, 他家, 一间, 包房, 他家, 挺, 老婆, 点, 几个,...
# 4     [开业, 那天, 环境, 一种, 温软, 感觉,  ,  , 服务, 销售, 耐心, 老公,...
# 5     [好像, 说, 宁波, 菜系, 东西, 上菜, 速度, 比较慢, 服务, 不错, 赠送, 餐...
# ...                                                 ...
# 9761  [苏浙, 汇吃, 新开, 家, 丰收, 日, 尝, 味道, 不错, 价格, 实惠, 贵, 包...
# 9762  [世界末日, 到来, 21, 号, 钱, 用光, TMD, 谁造, 谣, 剩, 100, 钱...
# 9763  [菜, 好吃, 剁, 椒, 鱼头, 强烈推荐, 建议, 老板, 稍微, 场地, 位置, 太,...
# 9764  [公司, 楼下,  , 好吃, 麻辣烫,  , 老板, 河南人,  , 煮, 麻辣烫, 小姑...
# 9765  [鸭, 王, 每桌, 点, 两道, 特价, 菜, 实惠, 菜, 味道, 周边, 朋友, 介绍...
#
# [9765 rows x 3 columns]

# %%
# labels to int   spam = 1, ham = 0

def label_to_num(label):
    return 1 if label == "+" else 0
data["labels"] = data["label"].apply(lambda x: label_to_num(x))



data
# Out:
#      label                                               text  \
# 1        +  他家的面很有嚼劲，牛肉汤很有味道，服务员的服务也特别的好，其中服务员顾存芳的服务特好！好喜欢...
# 2        -  鲜榨果汁很不错，水果都是很新鲜的，口感也很好，是个小妹妹态度非常好，环境也很好，但是专家告诉...
# 3        +  跟老婆过二人世界，就定了他家的一间包房，他家挺好的，跟老婆点了几个菜，边吃边聊，包房的话，那...
# 4        -  我是在开业那天去得，他们的环境很好，进去给人一种很温软的感觉  他们的服务很好，销售很耐心的...
# 5        -  好像说属于宁波菜系，东西还可以，只是上菜速度比较慢，好在服务还不错。还有赠送的餐前小吃，水果...
# ...    ...                                                ...
# 9761     +  之前一直在苏浙汇吃，看到这边新开了家丰收日就去尝了下，味道不错，价格也比较实惠，不是很贵，包...
# 9762     -  我一直等着世界末日的到来，等到21号，钱用光了，什么都没有了，结果它没有来，TMD谁造的谣啊...
# 9763     +       菜很好吃，尤其是剁椒鱼头，强烈推荐！！建议老板稍微扩大一下场地，位置太少！每次去都要等！
# 9764     -                   公司楼下 最好吃的麻辣烫 老板是河南人 煮麻辣烫的小姑娘长得不错
# 9765     +  经常去的鸭王，每天每桌还可以点两道特价菜。很实惠，菜的味道又好。我还经常给我周边的朋友介绍他...
#
#                                                   texts  labels
# 1     [他家, 面, 嚼, 劲, 牛肉汤, 味道, 服务员, 服务, 特别, 服务员, 顾存芳, ...       1
# 2     [鲜榨, 果汁, 不错, 水果, 新鲜, 口感, 小妹妹, 态度, 环境, 专家, 告诉, ...       0
# 3     [老婆, 二人, 世界, 就定, 他家, 一间, 包房, 他家, 挺, 老婆, 点, 几个,...       1
# 4     [开业, 那天, 环境, 一种, 温软, 感觉,  ,  , 服务, 销售, 耐心, 老公,...       0
# 5     [好像, 说, 宁波, 菜系, 东西, 上菜, 速度, 比较慢, 服务, 不错, 赠送, 餐...       0
# ...                                                 ...     ...
# 9761  [苏浙, 汇吃, 新开, 家, 丰收, 日, 尝, 味道, 不错, 价格, 实惠, 贵, 包...       1
# 9762  [世界末日, 到来, 21, 号, 钱, 用光, TMD, 谁造, 谣, 剩, 100, 钱...       0
# 9763  [菜, 好吃, 剁, 椒, 鱼头, 强烈推荐, 建议, 老板, 稍微, 场地, 位置, 太,...       1
# 9764  [公司, 楼下,  , 好吃, 麻辣烫,  , 老板, 河南人,  , 煮, 麻辣烫, 小姑...       0
# 9765  [鸭, 王, 每桌, 点, 两道, 特价, 菜, 实惠, 菜, 味道, 周边, 朋友, 介绍...       1
#
# [9765 rows x 4 columns]

# %%
# count unique words

def count_words(textset):
    count = Counter()
    max_tkn = 0
    for row in textset:
        i = 0
        for token in row:
            count[token] += 1
            i += 1
        max_tkn = i if i > max_tkn else max_tkn
    return count, max_tkn

words_statistic, max_token = count_words(data["texts"])
print(max_token)
print(len(words_statistic))
words_statistic
# Out:
# 832
# 22868
# Counter({'他家': 795,
#          '面': 661,
#          '嚼': 101,
#          '劲': 150,
#          '牛肉汤': 9,
#          '味道': 3931,
#          '服务员': 1738,
#          '服务': 2028,
#          '特别': 959,
#          '顾存芳': 194,
#          '特': 94,
#          '喜欢': 2585,
#          '鲜榨': 86,
#          '果汁': 138,
#          '不错': 5505,
#          '水果': 145,
#          '新鲜': 651,
#          '口感': 345,
#          '小妹妹': 5,
#          '态度': 435,
#          '环境': 1960,
#          '专家': 5,
#          '告诉': 61,
#          '吃水果': 9,
#          ' ': 24010,
#          '老婆': 60,
#          '二人': 4,
#          '世界': 17,
#          '就定': 10,
#          '一间': 25,
#          '包房': 256,
#          '挺': 1754,
#          '点': 1779,
#          '几个': 356,
#          '菜': 2132,
#          '吃': 7081,
#          '聊': 19,
#          '小姑娘': 148,
#          '两人': 17,
#          '打扰': 8,
#          '感到': 21,
#          '挺舒服': 18,
#          '开业': 77,
#          '那天': 77,
#          '一种': 110,
#          '温软': 1,
#          '感觉': 2116,
#          '销售': 28,
#          '耐心': 103,
#          '老公': 169,
#          '介绍': 287,
#          '口味': 1043,
#          '爆米花': 8,
#          '价格': 1084,
#          '性价比': 327,
#          '高': 273,
#          '总得来说': 7,
#          '服务态度': 380,
#          '实惠': 487,
#          '建议': 134,
#          '朋友': 1649,
#          '沃尔玛': 2,
#          '买': 658,
#          '~': 2977,
#          '好像': 294,
#          '说': 1617,
#          '宁波': 119,
#          '菜系': 25,
#          '东西': 851,
#          '上菜': 310,
#          '速度': 268,
#          '比较慢': 8,
#          '赠送': 26,
#          '餐前': 17,
#          '小吃': 105,
#          '送': 429,
#          '一点': 363,
#          '科学': 4,
#          '赞': 338,
#          '顺便': 66,
#          '零食': 17,
#          '热情': 537,
#          '2': 331,
#          '号线': 10,
#          '科技馆': 1,
#          '找': 262,
#          '好久': 63,
#          '地铁': 33,
#          '蛮远': 1,
#          '面包': 161,
#          '真心': 286,
#          '机会': 161,
#          '真想': 9,
#          '全买': 1,
#          '离谱': 9,
#          '红酒': 45,
#          '芝士': 131,
#          '超级': 256,
#          '满满的': 21,
#          '+_+': 2,
#          '昨天': 148,
#          '休息': 69,
#          '约': 86,
#          '鸭': 681,
#          '王': 285,
#          '想': 591,
#          '鸭子': 405,
#          '一只': 115,
#          '168': 30,
#          '元': 514,
#          '精品': 15,
#          '烤鸭': 1058,
#          '尝尝': 217,
#          '师傅': 72,
#          '片': 95,
#          '鸭架': 70,
#          '换汤': 2,
#          '鲜美': 146,
#          '下次': 872,
#          '选鸭王': 1,
#          '老牌子': 10,
#          '饭店': 611,
#          '外地': 15,
#          '时': 155,
#          '选择': 342,
#          '鸭王': 242,
#          '中': 182,
#          '烤鸭店': 25,
#          '太': 415,
#          '好吃': 2933,
#          '真的': 1430,
#          '实在': 254,
#          '没边': 1,
#          '难以形容': 1,
#          '甜品': 115,
#          '芋': 64,
#          '贵人': 63,
#          '前': 143,
#          '几天': 106,
#          '吃饭': 644,
#          '正好': 205,
#          '有人': 101,
#          '过生日': 62,
#          '帮': 209,
#          '蛋糕': 233,
#          '放进': 5,
#          '冰箱': 15,
#          '回族': 1,
#          '猪肉': 18,
#          '问': 159,
#          '汤底': 106,
#          '有没有': 28,
#          '主意': 1,
#          '单独': 7,
#          '点个': 29,
#          '小锅': 16,
#          '开水': 8,
#          '调料': 68,
#          '做': 1073,
#          '贴心': 68,
#          '奶茶': 397,
#          '手工': 40,
#          '很浓': 80,
#          '三明治': 22,
#          '肉': 451,
#          '美尔': 3,
#          '饿': 111,
#          '一杯': 245,
#          '足够': 39,
#          '这家': 1788,
#          '店': 1670,
#          '大地': 3,
#          '电影院': 6,
#          '对面': 71,
#          '多家': 26,
#          '小吃店': 9,
#          '5': 153,
#          '分熟': 9,
#          '倒': 257,
#          '下口': 3,
#          '咬': 40,
#          '不动': 9,
#          '7': 90,
#          '算了': 22,
#          '玉米汤': 2,
#          '鱼排': 7,
#          '挺嫩': 2,
#          '人去': 33,
#          '一份': 390,
#          'T': 10,
#          '骨': 54,
#          '45': 12,
#          '牛鱼': 1,
#          '双拼': 12,
#          '积分': 7,
#          '次': 62,
#          '免费送': 11,
#          '经典': 72,
#          '牛排': 188,
#          '价值': 12,
#          '35': 15,
#          '卖狗肉': 10,
#          '证明': 9,
#          '出处': 4,
#          '无耻': 5,
#          '商家': 17,
#          '倒霉': 8,
#          '第一次': 350,
#          '上海': 458,
#          '车站': 30,
#          '带我去': 24,
#          '来到': 110,
#          '康师傅': 489,
#          '我点': 62,
#          '新品': 72,
#          '金牌': 173,
#          '牛肉面': 661,
#          '宽': 20,
#          '汤': 503,
#          '这两点': 2,
#          '提前': 97,
#          '独立': 30,
#          '卫生间': 31,
#          '入口': 63,
#          '简单': 52,
#          '煮': 88,
#          '干丝': 9,
#          '烧': 163,
#          '油': 71,
#          '浓': 67,
#          '别提': 6,
#          '差': 392,
#          '鸡': 96,
#          '换换': 19,
#          '满意': 189,
#          '牛肉': 634,
#          '入味': 174,
#          '麻辣': 182,
#          '对胃口': 3,
#          '完': 254,
#          '意犹未尽': 9,
#          '刚去': 6,
#          '点评': 340,
#          '感想': 1,
#          '结婚': 43,
#          '酒店': 152,
#          '还行': 106,
#          '川菜': 43,
#          '团购': 393,
#          '双人': 17,
#          '套餐': 413,
#          '量': 377,
#          '两盆': 6,
#          '超多': 9,
#          '两个': 231,
#          '吃不完': 43,
#          '汤锅': 7,
#          '没什么': 202,
#          '特色': 465,
#          '土豆粉': 2,
#          '烧不烂': 1,
#          '炸豆': 1,
#          '皮超': 1,
#          '羊肉': 342,
#          '拼盘': 55,
#          '减少': 2,
#          '生菜': 21,
#          '吃不下': 18,
#          '店人': 3,
#          '超少': 2,
#          '四桌': 7,
#          '空调': 51,
#          '很小': 65,
#          '舒服': 229,
#          '别家': 44,
#          '一个样': 2,
#          '选': 138,
#          '红烧': 391,
#          '挺好吃': 131,
#          '点餐': 96,
#          '人员': 42,
#          '划算': 170,
#          '30': 97,
#          '块钱': 64,
#          '饱饱': 11,
#          '江': 46,
#          '想想': 115,
#          '一般般': 114,
#          '便宜': 386,
#          '安静': 159,
#          '!': 562,
#          '这厅': 1,
#          '很大': 344,
#          ',': 1599,
#          '家': 928,
#          '是从': 14,
#          '北京': 131,
#          '.': 663,
#          '火烤': 1,
#          '放心': 52,
#          '名以': 1,
#          '食为天': 1,
#          '万物': 1,
#          '土中生': 1,
#          '总': 73,
#          '菜肴': 79,
#          '学生': 34,
#          '记得': 88,
#          '虹桥': 62,
#          '火车站': 92,
#          '接': 23,
#          '私房': 241,
#          '秘制': 24,
#          '拌面': 63,
#          '牛': 72,
#          '三宝': 45,
#          '正点': 22,
#          '时间': 240,
#          '兄弟姐妹': 4,
#          '大厅': 90,
#          '吵闹': 16,
#          '小孩子': 30,
#          '哭': 8,
#          '闹': 7,
#          '清净': 10,
#          '再也': 50,
#          '周末': 135,
#          '开': 294,
#          '荒郊野外': 1,
#          '想以': 1,
#          '宴请': 73,
#          '可惜': 101,
#          '位置': 193,
#          '不佳': 3,
#          '客户群': 3,
#          '关门歇业': 1,
#          '晚上': 290,
#          '漆黑': 2,
#          '竹林': 6,
#          '建筑': 16,
#          '排': 86,
#          '十几': 3,
#          '二十分钟': 11,
#          '不算': 135,
#          '长': 76,
#          '一家': 713,
#          '吸引': 74,
#          '夸张': 15,
#          '中午': 329,
#          '一帮': 13,
#          '店铺': 54,
#          '新路': 5,
#          '高架': 4,
#          '装修': 420,
#          '气': 54,
#          '确实': 192,
#          '正宗': 307,
#          '阳澄湖': 20,
#          '大闸蟹': 64,
#          '鲜活': 4,
#          '蟹': 89,
#          '配有': 9,
#          '戒指': 3,
#          '查询': 2,
#          '防伪': 3,
#          '蟹黄': 20,
#          '爆满': 16,
#          '蟹肉': 18,
#          '蟹行': 11,
#          '天下': 18,
#          '聚会': 163,
#          '场所': 18,
#          '上次': 145,
#          '承接': 1,
#          '委员长': 1,
#          '同志': 7,
#          '委派': 1,
#          '外宾': 2,
#          '接待': 18,
#          '力': 50,
#          '木有': 28,
#          '开发': 8,
#          '新菜': 17,
#          '下班': 93,
#          '女朋友': 71,
#          '半只': 48,
#          '完整': 7,
#          '再点': 24,
#          '很快': 135,
#          '服务生': 50,
#          '勤快': 39,
#          '一顿饭': 37,
#          '骨碟': 3,
#          '换': 133,
#          '三个': 90,
#          '推荐': 775,
#          '试试': 169,
#          '绝味': 16,
#          '脖': 50,
#          '好多': 291,
#          '贵': 365,
#          '面条': 182,
#          '有劲': 49,
#          '道': 149,
#          '品种': 178,
#          '炖': 45,
#          '酥': 150,
#          '烂': 53,
#          '浓烈': 2,
#          '到位': 130,
#          '叫顾': 18,
#          '存芳': 18,
#          '周到': 152,
#          '友善': 5,
#          '下单': 13,
#          '超过': 15,
#          '分钟': 123,
#          '四个': 50,
#          '人点': 36,
#          '七个': 3,
#          '冷热': 4,
#          '菜全': 1,
#          '不见': 14,
#          '影子': 2,
#          '客人': 191,
#          '很香': 137,
#          '芥末': 97,
#          '鸭掌': 84,
#          '够味': 55,
#          '家庭聚会': 37,
#          '腐竹': 12,
#          '盖浇饭': 6,
#          '凉拌': 18,
#          '有时候': 80,
#          '分量': 194,
#          '行': 205,
#          '够': 107,
#          '辣': 262,
#          '老板': 784,
#          '客气': 70,
#          '鲜族': 1,
#          '先看': 2,
#          '菜单': 115,
#          '小贵': 109,
#          '一看': 61,
#          '量足': 18,
#          '食材': 90,
#          '冷冻': 8,
#          '嫌疑': 4,
#          '烤': 245,
#          '香': 269,
#          '地方': 822,
#          '还会': 315,
#          '泡': 42,
#          '菜汤': 8,
#          '合': 14,
#          '营业': 19,
#          '米兰': 1,
#          '汤是': 7,
#          '越式': 5,
#          '料': 83,
#          '太少': 53,
#          '搞': 81,
#          '阳春面': 4,
#          '价位': 46,
#          '吉亨': 1,
#          '四五倍': 1,
#          '回头': 4,
#          '就别': 2,
#          '顾客': 112,
#          '坑': 17,
#          '档次': 78,
#          '设计': 40,
#          '优雅': 118,
#          '气氛': 73,
#          '菜点': 7,
#          '蟹粉': 30,
#          '吃掉': 16,
#          '呼呼': 12,
#          '合口味': 16,
#          '足': 193,
#          '开心': 205,
#          '失望': 143,
#          '总想': 1,
#          '小费': 6,
#          '品尝': 139,
#          '几款': 9,
#          '新': 139,
#          '菜品': 220,
#          '异域': 1,
#          '风情': 24,
#          '适合': 391,
#          '?': 29,
#          '停车': 88,
#          '店面': 157,
#          '干净': 458,
#          '很足': 73,
#          '肉块': 8,
#          '牛骨': 9,
#          '熬出来': 11,
#          '汤汁': 60,
#          '好喝': 453,
#          '招牌': 198,
#          '大蒜': 10,
#          '炒': 59,
#          '牛舌': 21,
#          '美味': 257,
#          '那种': 227,
#          '青蒜': 2,
#          '从来不': 8,
#          '爆炒': 3,
#          '香气': 14,
#          '四溢': 13,
#          '好面': 4,
#          '汤类': 4,
#          '棒': 170,
#          '快餐店': 16,
#          '类': 46,
#          '值得称赞': 9,
#          '湘辣': 2,
#          '剁': 79,
#          '椒': 79,
#          '肥牛': 95,
#          '把面': 2,
#          '全是': 44,
#          '喝': 500,
#          '一口': 57,
#          '暖': 14,
#          '重': 48,
#          '香芹': 2,
#          '红油': 6,
#          '拌': 98,
#          '金针': 4,
#          '算是': 192,
#          '小菜': 161,
#          '每次': 403,
#          '吃面': 120,
#          '会点': 21,
#          '带去': 7,
#          '小料': 16,
#          '免费': 184,
#          '豆浆': 66,
#          '畅饮': 16,
#          '花生': 39,
#          '第三次': 6,
#          '发现': 265,
#          '两次': 43,
#          '不好意思': 37,
#          '没想到': 146,
#          '这是': 92,
#          '收钱': 9,
#          '1': 181,
#          '垃圾': 55,
#          '定好': 2,
#          '位子': 130,
#          '领班': 34,
#          '怎么回事': 5,
#          '理由': 13,
#          '真': 208,
#          '好笑': 1,
#          '原因': 64,
#          '付': 7,
#          '押金': 3,
#          '赶不回来': 1,
#          '来付': 1,
#          '再三': 1,
#          '没留': 1,
#          '难看': 8,
#          '死': 63,
#          '打电话': 46,
#          '预定': 73,
#          '同学': 114,
#          '冬瓜': 2,
#          '金针菇': 40,
#          '丸子': 32,
#          '种类': 79,
#          '宽敞': 56,
#          '拥挤': 13,
#          '常去': 14,
#          '灯': 31,
#          '很漂亮': 97,
#          '必点': 85,
#          '海鲜': 422,
#          '面疙瘩': 51,
#          '海瓜子': 183,
#          '茄子': 100,
#          '很多很多': 17,
#          '日本料理': 8,
#          '韩国': 61,
#          '料理': 56,
#          '样子': 137,
#          '随意': 19,
#          '专业': 58,
#          '卖': 104,
#          '伤不起': 4,
#          '萝卜': 7,
#          '腌制': 9,
#          '寿司': 31,
#          '咖喱': 79,
#          '虾': 270,
#          '难吃': 153,
#          '猪': 34,
#          '扒鸡': 1,
#          '扒': 6,
#          '去过': 181,
#          '光顾': 146,
#          '合算': 52,
#          '羊肉串': 25,
#          '飞饼': 71,
#          '远': 51,
#          '前天': 24,
#          '温馨': 117,
#          '捏': 8,
#          '泥巴': 1,
#          '坐': 161,
#          '现成': 2,
#          '胚子': 4,
#          '绘画': 10,
#          '店家': 114,
#          '负责': 15,
#          '一周': 18,
#          '通知': 8,
#          '取': 13,
#          '觉得很有': 6,
#          '希望': 291,
#          '常来': 11,
#          '整体': 82,
#          '小点': 9,
#          '冬天': 42,
#          '曲奇饼': 6,
#          '干': 61,
#          '夏天': 80,
#          '冰激凌': 29,
#          '搭配': 76,
#          '精美': 10,
#          '餐具': 34,
#          '无论是': 17,
#          '看书': 13,
#          '约会': 41,
#          '件': 4,
#          '惬意': 45,
#          '事': 28,
#          '店内': 63,
#          '小猫': 20,
#          '可爱': 107,
#          '悄悄': 1,
#          '跳上': 1,
#          '沙发': 41,
#          '安安静静': 7,
#          '乖乖': 3,
#          '摸': 2,
#          'wifi': 19,
#          '桌游': 24,
#          '书柜': 1,
#          '书': 14,
#          '提供': 55,
#          '寄': 16,
#          '明信片': 33,
#          '整家店': 1,
#          '休闲': 39,
#          '店里': 324,
#          '隔出': 1,
#          '一块': 76,
#          '天地': 5,
#          '每晚': 4,
#          '放': 119,
#          '电影': 67,
#          '44': 1,
#          '饮料': 306,
#          '加': 196,
#          '组合': 18,
#          '坐上': 3,
#          '下午': 127,
#          '时会': 3,
#          '添上': 3,
#          '柠檬水': 9,
#          '送上': 4,
#          '花茶': 4,
#          '普洱': 8,
#          '拿到': 34,
#          '优惠券': 19,
#          '试一试': 8,
#          '好不好': 12,
#          '两': 40,
#          '荤': 14,
#          '四素': 3,
#          '炒饭': 32,
#          '自助': 102,
#          '反正': 159,
#          '不用': 106,
#          '外面': 192,
#          '等位': 73,
#          '店菜': 2,
#          '地道': 131,
#          '鱼头': 138,
#          '嫩': 206,
#          '还来': 61,
#          '爽朗': 1,
#          '零头': 6,
#          '拉': 52,
#          '爆': 20,
#          '很赞': 81,
#          'O': 30,
#          '(': 125,
#          '∩': 28,
#          '_': 70,
#          ')': 160,
#          '大热': 2,
#          '天': 49,
#          '送来': 18,
#          '冰冰': 11,
#          '巧克力': 71,
#          '送人': 12,
#          '很棒': 122,
#          '好评': 52,
#          '好会': 1,
#          '促销': 4,
#          '试吃': 82,
#          '香芋': 28,
#          '蓝莓': 19,
#          '提拉': 21,
#          '米苏': 21,
#          '焦糖': 27,
#          '冰': 65,
#          '融化': 4,
#          '一会儿': 39,
#          '吃会': 1,
#          '总体': 305,
#          '逛': 69,
#          '大润发': 49,
#          '隔壁': 46,
#          '碗面': 11,
#          '龙头': 86,
#          '偏': 53,
#          '咸': 96,
#          '太小': 19,
#          '少': 263,
#          '不到': 164,
#          '要命': 10,
#          '半天': 60,
#          '人理': 11,
#          '草头': 5,
#          '里': 418,
#          '塑料纸': 1,
#          '不说': 13,
#          '嘴': 13,
#          '割破': 1,
#          '桌子': 128,
#          '关门': 78,
#          '菜谱': 11,
#          '老字号': 37,
#          '表演': 13,
#          '边乐': 1,
#          '纯正': 40,
#          '湖南': 11,
#          '土菜': 21,
#          '烧烤': 140,
#          '木炭': 2,
#          '超有': 5,
#          '超正': 1,
#          '碗': 91,
#          '不贵': 120,
#          '请客': 109,
#          '王订': 9,
#          '穿': 36,
#          '格格': 16,
#          '服': 14,
#          '迎宾': 67,
#          '领位': 4,
#          '带到': 14,
#          '靠窗': 30,
#          '环境卫生': 10,
#          '点单': 28,
#          '面带微笑': 9,
#          '笑': 19,
#          '好看': 99,
#          '有个': 141,
#          '小小的': 40,
#          '梨涡': 1,
#          '席间': 7,
#          '气派': 55,
#          '请客吃饭': 49,
#          '王蛮': 2,
#          '丢面子': 7,
#          '同事': 307,
#          '说芋': 2,
#          '几次': 184,
#          '鲜芋': 23,
#          '仙有': 1,
#          '区别': 33,
#          '离得': 7,
#          '风格': 133,
#          '皇宫': 16,
#          '气息': 19,
#          '十足': 44,
#          '养眼': 7,
#          '老爸': 28,
#          '老妈': 46,
#          '貌似': 127,
#          '旅游团': 2,
#          '名气': 22,
#          '大嘛': 2,
#          '值得': 325,
#          '推出': 37,
#          '满鼻': 2,
#          '色泽': 9,
#          '枣红': 3,
#          '油亮': 4,
#          '味美': 6,
#          '肉嫩': 10,
#          '奇香': 4,
#          '营养': 38,
#          '拔丝': 19,
#          '香蕉': 60,
#          '甜甜的': 44,
#          '水晶': 28,
#          '虾仁': 80,
#          '装点': 2,
#          '盘子': 46,
#          '大堂': 97,
#          '凉菜': 37,
#          '豆豉': 5,
#          '小黄鱼': 4,
#          '一塌糊涂': 13,
#          '菜来': 1,
#          '热菜': 106,
#          '98': 9,
#          '信价': 3,
#          '比太差': 1,
#          '酸菜鱼': 50,
#          '铁板': 34,
#          '酱': 98,
#          '清淡': 50,
#          '懒': 10,
#          '丰收': 178,
#          '日': 203,
#          '常客': 27,
#          '益气': 1,
#          '养生': 46,
#          '秋耳': 2,
#          '酸酸的': 20,
#          '挺不错': 265,
#          '月浦': 20,
#          '办': 101,
#          '婚宴': 42,
#          '市中心': 9,
#          '同级': 1,
#          'LEVEL': 1,
#          '低': 35,
#          '选在': 10,
#          '24': 13,
#          '小时': 105,
#          '经理人': 1,
#          '做生意': 16,
#          '住': 73,
#          '武威': 2,
#          '东路': 8,
#          '天冷': 12,
#          '还好': 245,
#          '外边': 3,
#          '搭': 20,
#          '帐篷': 2,
#          '叫外卖': 28,
#          '聊聊天': 39,
#          '爱': 349,
#          '哈哈哈': 149,
#          '〜': 362,
#          '午餐': 52,
#          '匆忙': 1,
#          '<': 8,
#          '遗憾': 21,
#          '改天': 11,
#          '色香': 2,
#          '啊啊啊': 190,
#          '终于': 71,
#          '在家': 42,
#          '噢': 37,
#          '两只': 20,
#          '喵': 14,
#          '星人': 4,
#          '一鸭': 21,
#          '片皮': 35,
#          '爽口': 78,
#          '配着': 11,
#          '一顿': 57,
#          '满嘴': 5,
#          '流油': 1,
#          '肥而': 31,
#          '不腻': 87,
#          '年纪': 8,
#          '诚恳': 2,
#          '但面': 4,
#          '相比': 40,
#          '相差': 5,
#          '甚远': 2,
#          '面量': 5,
#          '四块': 3,
#          '青菜': 53,
#          '一两个': 6,
#          '方便面': 132,
#          '一试': 34,
#          '给力': 43,
#          '招财猫': 4,
#          '猫': 24,
#          '蓝猫': 1,
#          '童鞋': 6,
#          '萌': 4,
#          '鸭舌': 48,
#          '我滴': 1,
#          '最爱': 37,
#          '哦哦哦': 14,
#          '卖相': 22,
#          '收费': 17,
#          '焖': 7,
#          '蹄面': 1,
#          '超': 111,
#          '花神': 101,
#          '咖啡馆': 61,
#          '优静': 1,
#          '几只': 9,
#          '路过': 229,
#          '随便': 203,
#          '回家': 135,
#          '一吃': 35,
#          '听说': 163,
#          '栗子': 8,
#          '出口': 7,
#          '大众': 76,
#          '网': 36,
#          '评论': 30,
#          '窝窝': 10,
#          '团': 43,
#          '贸然': 2,
#          '尝试': 126,
#          '体验': 52,
#          '点多': 17,
#          '餐厅': 288,
#          '3': 222,
#          '唯一': 62,
#          '一桌': 64,
#          '团上': 2,
#          '硬性': 1,
#          '点份餐': 1,
#          '无奈': 12,
#          '份': 114,
#          '披萨': 23,
#          '超贵': 1,
#          '100': 61,
#          '肋排': 11,
#          '满盘': 1,
#          '浇': 5,
#          '酱汁': 27,
#          '食欲': 51,
#          '有肉': 3,
#          '腥味': 17,
#          '放置': 3,
#          '一旁': 2,
#          '饭': 328,
#          '一个个': 23,
#          '幸好': 14,
#          '贝类': 5,
#          '买单': 75,
#          '提了': 5,
#          '无措': 1,
#          '支支吾吾': 1,
#          '解释': 20,
#          '交代': 3,
#          '出个': 3,
#          '店方': 4,
#          '回复': 1,
#          '赔钱': 2,
#          '降低': 4,
#          '品质': 58,
#          '索性': 6,
#          '带来': 19,
#          '不好': 191,
#          '影响': 29,
#          '家庭': 40,
#          '聚餐': 185,
#          '老来': 3,
#          '人多': 69,
#          '肯定': 140,
#          '放过': 6,
#          '味精': 32,
#          '系列': 27,
#          '不功': 1,
#          '型': 11,
#          '公司': 276,
#          '活动': 150,
#          '牌子': 41,
#          '味': 164,
#          '很甜': 39,
#          '很腻': 15,
#          '奶油味': 4,
#          '浓香': 8,
#          '相对来说': 11,
#          '原材料': 12,
#          '跟着': 22,
#          '小聚': 42,
#          '和蔼': 8,
#          ...})

# %%
# training and testing dataset

X_train_temp, X_test_temp, y_train, y_test = train_test_split(data["texts"], data["labels"], test_size = 0.2, shuffle = True, random_state = 0, stratify = data["labels"])

# %%
# tokenizer

tokenizer = Tokenizer(num_words = max_token)
tokenizer.fit_on_texts(X_train_temp)
word_index = tokenizer.word_index
word_index
# Out:
# {' ': 1,
#  '吃': 2,
#  '不错': 3,
#  '味道': 4,
#  '~': 5,
#  '好吃': 6,
#  '喜欢': 7,
#  '菜': 8,
#  '感觉': 9,
#  '服务': 10,
#  '环境': 11,
#  '这家': 12,
#  '挺': 13,
#  '点': 14,
#  '服务员': 15,
#  '店': 16,
#  '说': 17,
#  '朋友': 18,
#  ',': 19,
#  '真的': 20,
#  '价格': 21,
#  '烤鸭': 22,
#  '做': 23,
#  '口味': 24,
#  '特别': 25,
#  '家': 26,
#  '下次': 27,
#  '地方': 28,
#  '东西': 29,
#  '他家': 30,
#  '老板': 31,
#  '推荐': 32,
#  '一家': 33,
#  '鸭': 34,
#  '面': 35,
#  '买': 36,
#  '吃饭': 37,
#  '.': 38,
#  '新鲜': 39,
#  '牛肉': 40,
#  '牛肉面': 41,
#  '饭店': 42,
#  '想': 43,
#  '/': 44,
#  '!': 45,
#  '热情': 46,
#  '元': 47,
#  '实惠': 48,
#  '汤': 49,
#  "'": 50,
#  '喝': 51,
#  '康师傅': 52,
#  '上海': 53,
#  '好喝': 54,
#  '生意': 55,
#  '特色': 56,
#  '干净': 57,
#  '装修': 58,
#  '太': 59,
#  '态度': 60,
#  '肉': 61,
#  '里': 62,
#  '送': 63,
#  '套餐': 64,
#  '海鲜': 65,
#  '〜': 66,
#  '鸭子': 67,
#  '便宜': 68,
#  '团购': 69,
#  '每次': 70,
#  '适合': 71,
#  '一份': 72,
#  '服务态度': 73,
#  '崇明': 74,
#  '红烧': 75,
#  '奶茶': 76,
#  '量': 77,
#  '点评': 78,
#  '几个': 79,
#  '贵': 80,
#  '一点': 81,
#  '好好': 82,
#  '很大': 83,
#  '口感': 84,
#  '性价比': 85,
#  '第一次': 86,
#  '选择': 87,
#  '赞': 88,
#  '羊肉': 89,
#  '中午': 90,
#  '差': 91,
#  '爱': 92,
#  '饭': 93,
#  '茶': 94,
#  '还会': 95,
#  '上菜': 96,
#  '值得': 97,
#  '店里': 98,
#  '2': 99,
#  '同事': 100,
#  '正宗': 101,
#  '餐厅': 102,
#  '好像': 103,
#  '好多': 104,
#  '算': 105,
#  '总体': 106,
#  '饮料': 107,
#  '介绍': 108,
#  '开': 109,
#  '高': 110,
#  '希望': 111,
#  '真心': 112,
#  '公司': 113,
#  '晚上': 114,
#  '王': 115,
#  '速度': 116,
#  '挺不错': 117,
#  '香': 118,
#  '发现': 119,
#  '实在': 120,
#  '倒': 121,
#  '包房': 122,
#  '少': 123,
#  '找': 124,
#  '还好': 125,
#  '辣': 126,
#  '鱼': 127,
#  '完': 128,
#  '时间': 129,
#  '一杯': 130,
#  '蛋糕': 131,
#  '鸭王': 132,
#  '超级': 133,
#  '虾': 134,
#  '烤': 135,
#  '那种': 136,
#  '美味': 137,
#  '路过': 138,
#  '听': 139,
#  '菜品': 140,
#  '私房': 141,
#  '尝尝': 142,
#  '舒服': 143,
#  '两个': 144,
#  '真': 145,
#  '名字': 146,
#  '帮': 147,
#  '开心': 148,
#  '日': 149,
#  '没什么': 150,
#  '位置': 151,
#  '...': 152,
#  '嫩': 153,
#  '正好': 154,
#  '随便': 155,
#  '3': 156,
#  '足': 157,
#  '-': 158,
#  '走': 159,
#  '新开': 160,
#  '满意': 161,
#  '招牌': 162,
#  '排队': 163,
#  '算是': 164,
#  '确实': 165,
#  '顾存芳': 166,
#  '不好': 167,
#  '印象': 168,
#  '外面': 169,
#  '加': 170,
#  '咖啡': 171,
#  '=': 172,
#  '牛排': 173,
#  '客人': 174,
#  '几次': 175,
#  '聚餐': 176,
#  '消费': 177,
#  '分量': 178,
#  '免费': 179,
#  '中': 180,
#  '丰收': 181,
#  '海瓜子': 182,
#  '品种': 183,
#  '一碗': 184,
#  '去过': 185,
#  '火锅': 186,
#  '坐': 187,
#  '入味': 188,
#  '行': 189,
#  '老公': 190,
#  '试试': 191,
#  '面条': 192,
#  '本来': 193,
#  '棒': 194,
#  '请': 195,
#  '块': 196,
#  '麻辣': 197,
#  '聚会': 198,
#  '红豆': 199,
#  '看着': 200,
#  '玩': 201,
#  '4': 202,
#  '啊啊啊': 203,
#  '不到': 204,
#  '1': 205,
#  '听说': 206,
#  '活动': 207,
#  '面包': 208,
#  '金牌': 209,
#  '安静': 210,
#  '划算': 211,
#  '问': 212,
#  '机会': 213,
#  '蔬菜': 214,
#  '味': 215,
#  '店面': 216,
#  '10': 217,
#  '昨天': 218,
#  '^': 219,
#  '小店': 220,
#  '时': 221,
#  '劲': 222,
#  '烧': 223,
#  '浓郁': 224,
#  '反正': 225,
#  '小菜': 226,
#  '饼': 227,
#  '小姑娘': 228,
#  '水果': 229,
#  '酒店': 230,
#  '光顾': 231,
#  '周到': 232,
#  '酥': 233,
#  '难吃': 234,
#  '鲜美': 235,
#  '周末': 236,
#  '锅': 237,
#  '没想到': 238,
#  '道': 239,
#  '南方': 240,
#  '布丁': 241,
#  '选': 242,
#  '失望': 243,
#  '皮': 244,
#  '门口': 245,
#  '前': 246,
#  '肯定': 247,
#  '很香': 248,
#  '新': 249,
#  '鱼头': 250,
#  '5': 251,
#  '果汁': 252,
#  ')': 253,
#  '只能': 254,
#  '北京': 255,
#  '上次': 256,
#  '样子': 257,
#  '到位': 258,
#  '冷菜': 259,
#  '外卖': 260,
#  '位子': 261,
#  '打包': 262,
#  '生日': 263,
#  '很快': 264,
#  '哈哈哈': 265,
#  '芝士': 266,
#  '烧烤': 267,
#  '品尝': 268,
#  '地道': 269,
#  '享受': 270,
#  '下午': 271,
#  '风格': 272,
#  '建议': 273,
#  '换': 274,
#  '半价': 275,
#  '回家': 276,
#  '尝试': 277,
#  '有个': 278,
#  '不贵': 279,
#  '人气': 280,
#  '不算': 281,
#  '精致': 282,
#  '价钱': 283,
#  '卫生': 284,
#  '优雅': 285,
#  '方便面': 286,
#  '桌子': 287,
#  '旁边': 288,
#  '红烧肉': 289,
#  '估计': 290,
#  '貌似': 291,
#  '用餐': 292,
#  '热': 293,
#  '很棒': 294,
#  '#': 295,
#  '钱': 296,
#  '挺好吃': 297,
#  '一只': 298,
#  '店家': 299,
#  '顾客': 300,
#  '同学': 301,
#  '宁波': 302,
#  '想想': 303,
#  '裏': 304,
#  '平时': 305,
#  '支持': 306,
#  '锅底': 307,
#  '一种': 308,
#  '不用': 309,
#  '甜': 310,
#  '吃面': 311,
#  '杯': 312,
#  '订': 313,
#  '老师': 314,
#  '小贵': 315,
#  '鹅': 316,
#  '甜品': 317,
#  '汤底': 318,
#  'ok': 319,
#  '够': 320,
#  '路': 321,
#  '刺身': 322,
#  '还行': 323,
#  '超': 324,
#  '请客': 325,
#  '经理': 326,
#  '咸': 327,
#  '放': 328,
#  '8': 329,
#  '耐心': 330,
#  '温馨': 331,
#  '饿': 332,
#  '网上': 333,
#  '*': 334,
#  '面有個': 335,
#  '小蘿莉': 336,
#  '嚼': 337,
#  '肝': 338,
#  '有人': 339,
#  '号': 340,
#  '慢': 341,
#  '更好': 342,
#  '几天': 343,
#  '热菜': 344,
#  '自助': 345,
#  '葱油': 346,
#  '一般般': 347,
#  '可爱': 348,
#  '来到': 349,
#  '很漂亮': 350,
#  '(': 351,
#  '店员': 352,
#  '优惠': 353,
#  '好看': 354,
#  '包厢': 355,
#  '点菜': 356,
#  '菜单': 357,
#  '提前': 358,
#  '折': 359,
#  '家里': 360,
#  '份': 361,
#  '办': 362,
#  '鲈鱼': 363,
#  '卖': 364,
#  '分钟': 365,
#  '美食': 366,
#  '可惜': 367,
#  '酱': 368,
#  '接受': 369,
#  '健康': 370,
#  '找到': 371,
#  '煲': 372,
#  '下班': 373,
#  '电话': 374,
#  '拌': 375,
#  '肥牛': 376,
#  '菜式': 377,
#  '碗': 378,
#  '心情': 379,
#  '香味': 380,
#  '茄子': 381,
#  '特': 382,
#  '30': 383,
#  '鸡': 384,
#  '牛蛙': 385,
#  '大堂': 386,
#  '点餐': 387,
#  '片': 388,
#  '坐在': 389,
#  '很鲜': 390,
#  '龙虾': 391,
#  '小时': 392,
#  '家人': 393,
#  '更是': 394,
#  '点心': 395,
#  '不想': 396,
#  '会员卡': 397,
#  '长江': 398,
#  '料': 399,
#  '杯子': 400,
#  '7': 401,
#  '椒盐': 402,
#  '特色菜': 403,
#  '客户': 404,
#  '花神': 405,
#  '打折': 406,
#  '这是': 407,
#  '小吃': 408,
#  '配': 409,
#  '回去': 410,
#  '龙头': 411,
#  '芥末': 412,
#  '回来': 413,
#  '停车': 414,
#  '6': 415,
#  '亲切': 416,
#  '馄饨': 417,
#  '档次': 418,
#  '不腻': 419,
#  '大厅': 420,
#  '记得': 421,
#  '火车站': 422,
#  '排': 423,
#  '蟹': 424,
#  '约': 425,
#  '很赞': 426,
#  '很嫩': 427,
#  '尝': 428,
#  '字': 429,
#  '菜量': 430,
#  '芒果': 431,
#  '手': 432,
#  '烤羊': 433,
#  '鲜榨': 434,
#  '包子': 435,
#  '有时候': 436,
#  '试吃': 437,
#  '必点': 438,
#  '三个': 439,
#  '椒': 440,
#  '鸡蛋': 441,
#  '冷': 442,
#  '不行': 443,
#  '交通': 444,
#  '久': 445,
#  '有空': 446,
#  '剁': 447,
#  '土鸡': 448,
#  '拉面': 449,
#  '很浓': 450,
#  '稍微': 451,
#  '煮': 452,
#  '食材': 453,
#  '酱料': 454,
#  '长': 455,
#  '联洋': 456,
#  '虾仁': 457,
#  '干锅': 458,
#  '20': 459,
#  '鸭掌': 460,
#  '装潢': 461,
#  '关门': 462,
#  '种类': 463,
#  '菜肴': 464,
#  '豆腐': 465,
#  '搞': 466,
#  '可口': 467,
#  '买单': 468,
#  '份量': 469,
#  '整体': 470,
#  '大众': 471,
#  '嘻嘻': 472,
#  '包': 473,
#  '楼上': 474,
#  '鸭架': 475,
#  '删掉': 476,
#  '气氛': 477,
#  '电影': 478,
#  '一块': 479,
#  '厨师': 480,
#  '进门': 481,
#  '鸭汤': 482,
#  'q': 483,
#  '爽口': 484,
#  '油腻': 485,
#  '总': 486,
#  '广场': 487,
#  '牛奶': 488,
#  '独特': 489,
#  '商城': 490,
#  '鲜': 491,
#  '很足': 492,
#  '住': 493,
#  '开业': 494,
#  '咖喱': 495,
#  '预定': 496,
#  '骨头': 497,
#  '飞饼': 498,
#  '跑': 499,
#  '评价': 500,
#  '膏蟹': 501,
#  '女朋友': 502,
#  '忙': 503,
#  '休息': 504,
#  '台湾': 505,
#  '巧克力': 506,
#  '石锅': 507,
#  '抹': 508,
#  '对面': 509,
#  '面馆': 510,
#  '那天': 511,
#  '招牌菜': 512,
#  '等位': 513,
#  '真不错': 514,
#  '老板娘': 515,
#  '夏天': 516,
#  '浓': 517,
#  '弄': 518,
#  '漂亮': 519,
#  '舒适': 520,
#  '滴': 521,
#  '分店': 522,
#  '妈妈': 523,
#  '逛': 524,
#  '店内': 525,
#  '关键': 526,
#  '_': 527,
#  '冰': 528,
#  '晚': 529,
#  '下午茶': 530,
#  '还会来': 531,
#  '牛': 532,
#  '迎宾': 533,
#  '喝茶': 534,
#  '宴请': 535,
#  '+': 536,
#  '咯': 537,
#  '粉丝': 538,
#  '师傅': 539,
#  '豆腐衣': 540,
#  '月': 541,
#  '一张': 542,
#  '芋': 543,
#  '贵人': 544,
#  '品牌': 545,
#  '湘菜': 546,
#  '适中': 547,
#  '黄瓜': 548,
#  '终于': 549,
#  '第一': 550,
#  '很小': 551,
#  '鸡排': 552,
#  '人均': 553,
#  '吸引': 554,
#  '先': 555,
#  '番茄': 556,
#  '开张': 557,
#  '上班': 558,
#  '新品': 559,
#  '顺便': 560,
#  '吃火锅': 561,
#  '100': 562,
#  '天气': 563,
#  ':': 564,
#  '原因': 565,
#  '汤汁': 566,
#  '搭配': 567,
#  '拌面': 568,
#  '全聚德': 569,
#  '我点': 570,
#  '一桌': 571,
#  '块钱': 572,
#  '�': 573,
#  '香蕉': 574,
#  '还来': 575,
#  '肚子': 576,
#  '地段': 577,
#  '滑': 578,
#  '唯一': 579,
#  '次': 580,
#  '人多': 581,
#  '过生日': 582,
#  '咖啡馆': 583,
#  '豆浆': 584,
#  '胃口': 585,
#  '调料': 586,
#  '弄堂': 587,
#  '油': 588,
#  '火车': 589,
#  '干': 590,
#  '够味': 591,
#  '酒水': 592,
#  '出差': 593,
#  '气派': 594,
#  '客气': 595,
#  '一道': 596,
#  '米饭': 597,
#  '食物': 598,
#  '入口': 599,
#  '死': 600,
#  '第二杯': 601,
#  '白米': 602,
#  '深刻': 603,
#  '韩国': 604,
#  '我家': 605,
#  '\\': 606,
#  '牛筋': 607,
#  '写': 608,
#  '外': 609,
#  '经典': 610,
#  '仙草': 611,
#  '肉质': 612,
#  '饮': 613,
#  '好久': 614,
#  '汁': 615,
#  '贴心': 616,
#  '白斩鸡': 617,
#  '越来越': 618,
#  '早上': 619,
#  '一口': 620,
#  '忘记': 621,
#  '炒': 622,
#  '老婆': 623,
#  '一看': 624,
#  '还点': 625,
#  '情侣': 626,
#  '解决': 627,
#  '没话说': 628,
#  '额': 629,
#  '话': 630,
#  '..': 631,
#  '吃货': 632,
#  '粉': 633,
#  '午饭': 634,
#  'o': 635,
#  '质量': 636,
#  '男朋友': 637,
#  '年': 638,
#  '氛围': 639,
#  '鲜嫩': 640,
#  '酒吧': 641,
#  '期待': 642,
#  '卡': 643,
#  '特意': 644,
#  '生': 645,
#  '装饰': 646,
#  '一顿': 647,
#  '偏': 648,
#  '脖': 649,
#  '过瘾': 650,
#  '清爽': 651,
#  '制作': 652,
#  '关系': 653,
#  '一会': 654,
#  '告诉': 655,
#  '花': 656,
#  '不像': 657,
#  '提供': 658,
#  '虹桥': 659,
#  '宝宝': 660,
#  '主动': 661,
#  '品质': 662,
#  '好大': 663,
#  '二楼': 664,
#  '冰淇淋': 665,
#  '颜色': 666,
#  '烤鱼': 667,
#  '坐下': 668,
#  '糕': 669,
#  '专业': 670,
#  '午餐': 671,
#  '太少': 672,
#  '掉': 673,
#  '大闸蟹': 674,
#  '分': 675,
#  '气': 676,
#  '大爱': 677,
#  '三文鱼': 678,
#  '价位': 679,
#  '聊天': 680,
#  '菜色': 681,
#  '事情': 682,
#  '一共': 683,
#  '料理': 684,
#  '\u3000': 685,
#  '画': 686,
#  '想到': 687,
#  '半天': 688,
#  '体验': 689,
#  '至少': 690,
#  '拼盘': 691,
#  '办法': 692,
#  '券': 693,
#  '12': 694,
#  '合算': 695,
#  '很饱': 696,
#  '烂': 697,
#  '四个': 698,
#  '特价': 699,
#  '店铺': 700,
#  '汤头': 701,
#  '清蒸': 702,
#  '放心': 703,
#  '力': 704,
#  '柠檬': 705,
#  '鸭肉': 706,
#  '首选': 707,
#  '好评': 708,
#  '包间': 709,
#  '重': 710,
#  '鱿鱼': 711,
#  '硬': 712,
#  '进': 713,
#  '类': 714,
#  '请客吃饭': 715,
#  '试试看': 716,
#  '座位': 717,
#  '奶油': 718,
#  '蘸': 719,
#  '啤酒': 720,
#  '陶艺': 721,
#  '嗲': 722,
#  '骨': 723,
#  '有劲': 724,
#  '空调': 725,
#  '商务': 726,
#  '宽敞': 727,
#  '逛街': 728,
#  '辣辣的': 729,
#  '音乐': 730,
#  '刚刚': 731,
#  '情调': 732,
#  '一点点': 733,
#  '是因为': 734,
#  '扇贝': 735,
#  '好去处': 736,
#  '好找': 737,
#  '布置': 738,
#  '早': 739,
#  '小火锅': 740,
#  '盘子': 741,
#  '腻': 742,
#  '给力': 743,
#  '配菜': 744,
#  '员工': 745,
#  '差差': 746,
#  '酸菜鱼': 747,
#  '清淡': 748,
#  '个头': 749,
#  '天': 750,
#  '江': 751,
#  '坐坐': 752,
#  '西班牙': 753,
#  '鱼肉': 754,
#  '结婚': 755,
#  '孩子': 756,
#  '羊': 757,
#  '再也': 758,
#  '远': 759,
#  '•': 760,
#  '半筋': 761,
#  '玉米': 762,
#  '煎': 763,
#  '第二次': 764,
#  '68': 765,
#  '@': 766,
#  '放在': 767,
#  '上餐': 768,
#  '隔壁': 769,
#  '不怎么样': 770,
#  '服务生': 771,
#  '团': 772,
#  '中国': 773,
#  '十足': 774,
#  '外送': 775,
#  '面疙瘩': 776,
#  'diy': 777,
#  '50': 778,
#  '食欲': 779,
#  '不吃': 780,
#  '热闹': 781,
#  '吃饱': 782,
#  '公道': 783,
#  '日本': 784,
#  '惊喜': 785,
#  '不錯': 786,
#  '牡丹': 787,
#  '寿喜锅': 788,
#  '不太': 789,
#  '简单': 790,
#  '半只': 791,
#  '学校': 792,
#  '天天': 793,
#  '惬意': 794,
#  '细心': 795,
#  '泡': 796,
#  '老妈': 797,
#  '小聚': 798,
#  '正': 799,
#  '错': 800,
#  '懂': 801,
#  '青菜': 802,
#  '打电话': 803,
#  '十元': 804,
#  '麻辣烫': 805,
#  '食堂': 806,
#  '预约': 807,
#  '鸭舌': 808,
#  '烤肉': 809,
#  '中规中矩': 810,
#  '甜点': 811,
#  '三宝': 812,
#  '风味': 813,
#  '一如既往': 814,
#  '帮忙': 815,
#  '喔': 816,
#  '没吃过': 817,
#  '吃个': 818,
#  '催': 819,
#  '甜甜的': 820,
#  '儿子': 821,
#  '大块': 822,
#  '酸': 823,
#  '超好': 824,
#  '端上来': 825,
#  '说实话': 826,
#  '产品': 827,
#  '衣服': 828,
#  '高档': 829,
#  '约会': 830,
#  '养生': 831,
#  '酒': 832,
#  '时尚': 833,
#  '一楼': 834,
#  '自然': 835,
#  '撑': 836,
#  '素质': 837,
#  '沙发': 838,
#  '难': 839,
#  '半个': 840,
#  '家庭': 841,
#  '脆': 842,
#  '在家': 843,
#  '早餐': 844,
#  '清新': 845,
#  '很爽': 846,
#  '大润发': 847,
#  '15': 848,
#  '口': 849,
#  '金针菇': 850,
#  '芝麻': 851,
#  '两': 852,
#  '老外': 853,
#  '整洁': 854,
#  '超市': 855,
#  '排骨': 856,
#  '咖啡店': 857,
#  '两份': 858,
#  '晚饭': 859,
#  '店主': 860,
#  '辣椒': 861,
#  '五花肉': 862,
#  '几家': 863,
#  '手工': 864,
#  '打算': 865,
#  '新店': 866,
#  '别家': 867,
#  '珍珠': 868,
#  '淡淡的': 869,
#  '我要': 870,
#  '9': 871,
#  '用心': 872,
#  '吃不完': 873,
#  '太好了': 874,
#  '也许': 875,
#  '设计': 876,
#  '超赞': 877,
#  '可乐': 878,
#  '鸡肉': 879,
#  '一会儿': 880,
#  '一股': 881,
#  '符合': 882,
#  '旅游': 883,
#  '紫米': 884,
#  '咬': 885,
#  '一去': 886,
#  '缘故': 887,
#  '川菜': 888,
#  '蒸': 889,
#  '赞赞': 890,
#  '木瓜': 891,
#  '回': 892,
#  '厨房': 893,
#  '家里人': 894,
#  '牧羊': 895,
#  '凉菜': 896,
#  '铁板': 897,
#  '聊聊天': 898,
#  '走进': 899,
#  '人员': 900,
#  '热心': 901,
#  '几块': 902,
#  '小孩': 903,
#  '累': 904,
#  '多点': 905,
#  '那家': 906,
#  '好极了': 907,
#  '地理位置': 908,
#  '喝喝': 909,
#  '合适': 910,
#  '诱人': 911,
#  '一半': 912,
#  '提醒': 913,
#  '还给': 914,
#  '足够': 915,
#  '厚': 916,
#  '楼下': 917,
#  '红酒': 918,
#  '有名': 919,
#  '牌子': 920,
#  '200': 921,
#  '糯': 922,
#  '空间': 923,
#  '全是': 924,
#  '花生': 925,
#  '冬天': 926,
#  '小资': 927,
#  '米': 928,
#  '张': 929,
#  '年糕': 930,
#  '88': 931,
#  '学生': 932,
#  '房间': 933,
#  '强烈推荐': 934,
#  '抱': 935,
#  '一句': 936,
#  '结账': 937,
#  '偶然': 938,
#  '38': 939,
#  '物美价廉': 940,
#  '要点': 941,
#  '一顿饭': 942,
#  '单位': 943,
#  '谢谢': 944,
#  '珍珠奶茶': 945,
#  '再来': 946,
#  '特地': 947,
#  '浪费': 948,
#  '小小的': 949,
#  '一大': 950,
#  '弹性': 951,
#  '纯正': 952,
#  '白玉': 953,
#  '大学城': 954,
#  '人不多': 955,
#  '木耳': 956,
#  '很甜': 957,
#  '婚宴': 958,
#  '陈纹': 959,
#  '完美': 960,
#  '不去': 961,
#  '丸': 962,
#  '放松': 963,
#  '酸奶': 964,
#  '炖': 965,
#  '垃圾': 966,
#  '相比': 967,
#  '单点': 968,
#  '错过': 969,
#  '拉': 970,
#  '米粉': 971,
#  '很差': 972,
#  '网': 973,
#  '贝': 974,
#  '挤': 975,
#  '片皮': 976,
#  '像是': 977,
#  '吃点': 978,
#  '想着': 979,
#  '阿姨': 980,
#  '没事': 981,
#  '传统': 982,
#  '离家': 983,
#  '指导': 984,
#  '翅': 985,
#  '一人': 986,
#  '最爱': 987,
#  '人少': 988,
#  '路上': 989,
#  '礼貌': 990,
#  '晚餐': 991,
#  '发': 992,
#  '不好意思': 993,
#  '美': 994,
#  '有种': 995,
#  '雪菜': 996,
#  '叫江': 997,
#  '农家': 998,
#  '穿': 999,
#  '大气': 1000,
#  ...}

# %%
# train sequences

X_train_sequences = tokenizer.texts_to_sequences(X_train_temp)
X_train = pad_sequences(X_train_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_train.shape
# Out:
# (7812, 832)

# %%
# test sequences

X_test_sequences = tokenizer.texts_to_sequences(X_test_temp)
X_test = pad_sequences(X_test_sequences, maxlen = max_token, padding = "post", truncating = "post")
X_test.shape
# Out:
# (1953, 832)

# %%
# model

model = Sequential()
model.add(Embedding(len(words_statistic), 32, input_length = max_token))
model.add(LSTM(64, dropout = .1))
model.add(Dense(1, activation = "sigmoid"))

optimizer = Adam(lr=8e-7)

model.compile(loss = "binary_crossentropy", optimizer = optimizer, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 832, 32)           731776
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 756,673
# Trainable params: 756,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(X_train, y_train, epochs = 10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 245/245 [==============================] - 74s 303ms/step - loss: 0.6938 - accuracy: 0.3680 - val_loss: 0.6935 - val_accuracy: 0.3610
# Epoch 2/10
# 245/245 [==============================] - 68s 277ms/step - loss: 0.6932 - accuracy: 0.4785 - val_loss: 0.6929 - val_accuracy: 0.6390
# Epoch 3/10
# 245/245 [==============================] - 66s 271ms/step - loss: 0.6926 - accuracy: 0.6266 - val_loss: 0.6924 - val_accuracy: 0.6390
# Epoch 4/10
# 245/245 [==============================] - 66s 269ms/step - loss: 0.6921 - accuracy: 0.6391 - val_loss: 0.6918 - val_accuracy: 0.6390
# Epoch 5/10
# 245/245 [==============================] - 65s 266ms/step - loss: 0.6915 - accuracy: 0.6391 - val_loss: 0.6912 - val_accuracy: 0.6390
# Epoch 6/10
# 245/245 [==============================] - 64s 262ms/step - loss: 0.6910 - accuracy: 0.6391 - val_loss: 0.6907 - val_accuracy: 0.6390
# Epoch 7/10
# 245/245 [==============================] - 64s 263ms/step - loss: 0.6904 - accuracy: 0.6391 - val_loss: 0.6901 - val_accuracy: 0.6390
# Epoch 8/10
# 245/245 [==============================] - 64s 262ms/step - loss: 0.6898 - accuracy: 0.6391 - val_loss: 0.6896 - val_accuracy: 0.6390
# Epoch 9/10
# 245/245 [==============================] - 64s 262ms/step - loss: 0.6893 - accuracy: 0.6391 - val_loss: 0.6890 - val_accuracy: 0.6390
# Epoch 10/10
# 245/245 [==============================] - 64s 263ms/step - loss: 0.6888 - accuracy: 0.6391 - val_loss: 0.6885 - val_accuracy: 0.6390

# %%
# model2

model2 = Sequential()
model2.add(Embedding(len(words_statistic), 32, input_length = max_token))
model2.add(LSTM(64, dropout = .1))
model2.add(Dense(1, activation = "sigmoid"))

optimizer = Adam(lr=2e-6)

model2.compile(loss = "binary_crossentropy", optimizer = optimizer, metrics = ["accuracy"])
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 832, 32)           731776
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 756,673
# Trainable params: 756,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
result2 = model2.fit(X_train, y_train, epochs = 10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 245/245 [==============================] - 74s 303ms/step - loss: 0.6963 - accuracy: 0.3609 - val_loss: 0.6953 - val_accuracy: 0.3610
# Epoch 2/10
# 245/245 [==============================] - 67s 273ms/step - loss: 0.6944 - accuracy: 0.3665 - val_loss: 0.6935 - val_accuracy: 0.3610
# Epoch 3/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6926 - accuracy: 0.5876 - val_loss: 0.6916 - val_accuracy: 0.6390
# Epoch 4/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6907 - accuracy: 0.6391 - val_loss: 0.6898 - val_accuracy: 0.6390
# Epoch 5/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6889 - accuracy: 0.6391 - val_loss: 0.6880 - val_accuracy: 0.6390
# Epoch 6/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6870 - accuracy: 0.6391 - val_loss: 0.6860 - val_accuracy: 0.6390
# Epoch 7/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6851 - accuracy: 0.6391 - val_loss: 0.6840 - val_accuracy: 0.6390
# Epoch 8/10
# 245/245 [==============================] - 67s 273ms/step - loss: 0.6830 - accuracy: 0.6391 - val_loss: 0.6819 - val_accuracy: 0.6390
# Epoch 9/10
# 245/245 [==============================] - 67s 273ms/step - loss: 0.6808 - accuracy: 0.6391 - val_loss: 0.6796 - val_accuracy: 0.6390
# Epoch 10/10
# 245/245 [==============================] - 67s 274ms/step - loss: 0.6784 - accuracy: 0.6391 - val_loss: 0.6772 - val_accuracy: 0.6390

# %%
# index = dict([(value, key) for (key, value) in word_index.items()])
# def get_original_text(text):
#     return "".join([index.get(i, "") for i in text])
